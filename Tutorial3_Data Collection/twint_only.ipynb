# %% [markdown]
# # Data Collection - Twitter (Twint)
#
# Selain menggunakan Tweepy, pengumpulan data <i>tweet</i> dapat juga dilakukan dengan menggunakan <i>library</i> <a href='https://github.com/twintproject/twint'>Twint</a>. Perbedaan <i>library</i> ini dengan Tweepy adalah tidak membutuhkan <i>access token</i> Twitter API.
#
# Berikut merupakan contoh penggunaan Twint dalam melakukan <i>crawling tweet</i>:

# %%
# import library
import twint
import nest_asyncio

nest_asyncio.apply()

# %%
# need time about 10-15 mins

c = twint.Config()
keyword = 'vaksin'
c.Search = keyword # masukkan kata kunci
c.Since = '2022-5-18 00:00:00'
c.Until = '2022-5-18 1:59:59' 
c.Store_csv = True
c.Output = '{}.csv'.format(keyword)
c.Hide_output = True

twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\ichsan\Documents\proj\ams\tutorial3_Data Collection\twint_only.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/twint_only.ipynb#ch0000003?line=0'>1</a> # need time about 10-15 mins
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/twint_only.ipynb#ch0000003?line=2'>3</a> c = twint.Config()
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/twint_only.ipynb#ch0000003?line=3'>4</a> keyword = 'vaksin'
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/twint_only.ipynb#ch0000003?line=4'>5</a> c.Search = keyword # masukkan kata kunci
#
# ...

# %%
import twint

# Configure
c = twint.Config()
keyword = 'vaksin'
c.Search = keyword # masukkan kata kunci

c.Since = '2022-03-15 00:00:00'
c.Until = '2022-03-15 23:59:59'  
c.Store_csv = True
c.Output = "/vaksin/" c.Since + "." + c.Until ".csv"
c.Hide_output = True

# Run
twint.run.Search(c)

# %%
import datetime

start = datetime.datetime(2021, 1, 13)
end = datetime.datetime(2022, 1, 13)



# 12 Januari 2022

# %%
import twint
from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2021, 1, 13)
end_date = date(2022, 1, 13)
for single_date in daterange(start_date, end_date):
    print(single_date.strftime("%Y-%m-%d"))

    # Configure
    c = twint.Config()
    keyword = 'vaksin'
    c.Search = keyword # masukkan kata kunci

    c.Since = single_date.strftime("%Y-%m-%d") + ' 00:00:00'
    c.Until = single_date.strftime("%Y-%m-%d") + ' 23:59:59'  
    c.Store_csv = True
    c.Output = single_date.strftime("%Y-%m-%d") +".csv"
    c.Hide_output = True

    # Run
    twint.run.Search(c)
# Out:
# 2013-01-01
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2013-01-16
# 2013-01-17
# 2013-01-18
# 2013-01-19
# 2013-01-20
# 2013-01-21
# 2013-01-22
# 2013-01-23
# 2013-01-24
# 2013-01-25
# 2013-01-26
# 2013-01-27
# 2013-01-28
# 2013-01-29
# 2013-01-30
# 2013-01-31
# 2013-02-01
# 2013-02-02
# 2013-02-03
# 2013-02-04
# 2013-02-05
# 2013-02-06
# 2013-02-07
# 2013-02-08
# 2013-02-09
# 2013-02-10
# 2013-02-11
# 2013-02-12
# 2013-02-13
# 2013-02-14
# 2013-02-15
# 2013-02-16
# 2013-02-17
# 2013-02-18
# 2013-02-19
# 2013-02-20
# 2013-02-21
# 2013-02-22
# 2013-02-23
# 2013-02-24
# 2013-02-25
# 2013-02-26
# 2013-02-27
# 2013-02-28
# 2013-03-01
# 2013-03-02
# 2013-03-03
# 2013-03-04
# 2013-03-05
# 2013-03-06
# 2013-03-07
# 2013-03-08
# 2013-03-09
# 2013-03-10
# 2013-03-11
# 2013-03-12
# 2013-03-13
# 2013-03-14
# 2013-03-15
# 2013-03-16
# 2013-03-17
# ...

# %%
# Tweepy

# %%
# tweet_text_test = api.get_status(id=1285726236120166400).text
# # Authorize our Twitter credentials
# auth = tweepy.OAuthHandler(acct_twitter_1.api_key.values[0], acct_twitter_1.api_key_secret.values[0])
# auth.set_access_token(acct_twitter_1.access_token.values[0], acct_twitter_1.access_token_secret.values[0])
# api = tweepy.API(auth)
# tweet_text_test = api.get_status(id=1285726236120166400).text
