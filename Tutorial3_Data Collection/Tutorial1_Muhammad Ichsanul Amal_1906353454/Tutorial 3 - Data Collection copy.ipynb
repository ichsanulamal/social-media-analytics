# %% [markdown]
# # Tutorial 3 - Data Collection

# %% [markdown]
# Nama: Muhammad Ichsanul Amal
# <br>
# NPM: 1906353454

# %% [markdown]
# Pada tutorial ini, kita akan melakukan:
# 1. Pengumpulan data dari Twitter menggunakan Tweepy (dengan Twitter Search API), Twint, dan Twecoll. Terdapat tiga jenis data yang akan kita kumpulkan, yaitu data <i>tweet</i>, data profil, dan data <i>network</i>.
# 2. Pengumpulan data dari Instagram dengan instaloader.
# 3. Pengumpulan data dari Linkedin dengan <i>web scraping</i>.
#
# Sebelum memulai tutorial, kita akan menginstal <i>library</i> yang kita perlukan:

# %% [markdown]
# # Data Collection - Twitter (Tweepy)

# %% [markdown]
# ## Twitter Search API
#
# Pengumpulan data <i>tweet</i> dapat dilakukan dengan menggunakan Twitter API. Terdapat dua kategori API Twitter, yaitu Twitter Search API dan Twitter Streaming API. Perbedaan mendasar dari kedua jenis API tersebut adalah pada waktu data <i>tweet</i> yang akan dikumpulkan. Twitter Search API mengambil data <i>past tweet</i>, yaitu data <i>tweet</i> dengan kriteria tertentu yang diposting pada rentang waktu H-7 hari sampai dengan waktu <i>crawling</i>. Sementara itu, Twitter Streaming API akan mengambil data secara <i>real-time</i> pada saat program <i>crawling</i> dijalankan. Untuk memanggil kedua API tersebut, akan digunakan <i>library</i> Tweepy.
#
# Langkah-langkah untuk melakukan proses <i>search tweet data</i> adalah sebagai berikut:

# %%
# import library
import tweepy

# %% [markdown]
# ### Bearer token variable
#
# Pertama-tama, kita harus mendaftarkan akun Twitter kita agar dapat menggunakan API. Mengikuti panduan untuk Twitter API v2, berikutnya kita perlu membuat sebuah proyek. Dari proyek tersebut kita dapat peroleh *bearer token*-nya. *Bearer token* tersebut wajib dimasukkan ke dalam parameter penggunaan Tweepy.

# %%
bearer_token = "" # diisi

# %% [markdown]
# ### Setting client
#
# Pada tahap ini, kita membuat <i>client</i>  Tweepy dengan menggunakan otentikasi *bearer token*.

# %%
tweepy_client = tweepy.Client(bearer_token=bearer_token)

# %% [markdown]
# ### Crawling tweet berdasarkan query
#
# Pada contoh <b>Code 1</b> di bawah ini, <i>tweet</i> yang ingin dicari adalah 10 <i>tweet</i> yang mengandung kata `ppkm` dan berbahasa Indonesia. Menggunakan method `search_recent_tweets()`, kita bisa mendapatkan *tweet* yang memenuhi kriteria *query* hingga 7 hari yang lalu.
#
# Untuk mengetahui lebih lanjut soal *query search* di Twitter, bisa dibaca pada halaman ini: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query
#
# <b>Code 1</b>:

# %%
ppkm = tweepy_client.search_recent_tweets(query="ppkm lang:id", max_results=10)

print("Jumlah tweet yang berhasil didapatkan: {}.\n".format(len(ppkm.data)))
# Out:
# Jumlah tweet yang berhasil didapatkan: 10.

# %%
# objek ppkm
ppkm
# Out:
#  <Tweet id=1506197447311200257 text='RT @detikcom: Aturan PPKM level 2 di wilayah Jawa dan Bali kembali diperbarui. Ini isi lengkapnya dalam Inmendagri No 18 Tahun 2022. https:…'>,
#  <Tweet id=1506197423370424328 text='RT @karirmuid: Tau gak?\n\nKalau HRD suka lampiran CV seperti ini!!!\n\n#ONEPIECE1044\nPPKM https://t.co/2NmFTuOL1v'>,
#  <Tweet id=1506197363257454598 text='Operasi yustisi dalam rangka ppkm level 3 di wilayah kec.Sawit @ Boyolali, Jawa Tengah, Indonesia https://t.co/xI4iVcJeJ7'>,
#  <Tweet id=1506197249709129739 text='Sastus Terbaru Daerah PPKM Level 1 hingga 3 di Jawa Bali https://t.co/KHv20punX3'>,
#  <Tweet id=1506197248639893507 text='Kota Semarang Masuk  PPKM Level 2, Hendi Minta Warga untuk Segera Vaksinasi Booster\n\n#vaksin \n#PPKM\n#boster\n\n@suaramerdeka\n@hendrarprihadi\n@PemkotSmg\n\nhttps://t.co/8gGKfgPur8'>]

# %%
# parse ke format tabular (pandas dataframe)
import pandas as pd
pd.set_option('max_colwidth', 1000)

df_ppkm = pd.DataFrame()
for t in ppkm.data:
    df_ppkm = df_ppkm.append({
        'id': t.id,
        'text': t.text
    }, ignore_index=True)

df_ppkm
# Out:
#              id  \
# 0  1.506198e+18
# 1  1.506198e+18
# 2  1.506198e+18
# 3  1.506198e+18
# 4  1.506197e+18
# 5  1.506197e+18
# 6  1.506197e+18
# 7  1.506197e+18
# 8  1.506197e+18
# 9  1.506197e+18
#
#                                                                                                                                                                                        text
# 0                                              RT @Bebque__: Sudah selesai gelaran MotoGP, sekarang muncul PPKM lagi untuk Jawa-Bali. Padahal bentar lagi ramadhan dan lebaran. Kurva kopi…
# 1                                              RT @Bebque__: Sudah selesai gelaran MotoGP, sekarang muncul PPKM lagi untuk Jawa-Bali. Padahal bentar lagi ramadhan dan lebaran. Kurva kopi…
# 2                                                                                                                                        @Bebque__ Agar ppkm lg...🤭 https://t.co/4uMMhxdvQI
# 3                                         RT @DeeJee_007: Oyen pulang klo dijemput 😍😁\n🤭😁🙈😂\n\nTongkrongan Tempe Purwokerto\nCloud Engineer Anies Indonesia\nSenin Selasa Sarapan pagii Ep…
# 4                                              RT @Bebque__: Sudah selesai gelaran MotoGP, sekarang muncul PPKM lagi untuk Jawa-Bali. Padahal bentar lagi ramadhan dan lebaran. Kurva kopi…
# 5                                              RT @detikcom: Aturan PPKM level 2 di wilayah Jawa dan Bali kembali diperbarui. Ini isi lengkapnya dalam Inmendagri No 18 Tahun 2022. https:…
# 6                                                                       RT @karirmuid: Tau gak?\n\nKalau HRD suka lampiran CV seperti ini!!!\n\n#ONEPIECE1044\nPPKM https://t.co/2NmFTuOL1v
# 7                                                                 Operasi yustisi dalam rangka ppkm level 3 di wilayah kec.Sawit @ Boyolali, Jawa Tengah, Indonesia https://t.co/xI4iVcJeJ7
# 8                                                                                                          Sastus Terbaru Daerah PPKM Level 1 hingga 3 di Jawa Bali https://t.co/KHv20punX3
# 9  Kota Semarang Masuk  PPKM Level 2, Hendi Minta Warga untuk Segera Vaksinasi Booster\n\n#vaksin \n#PPKM\n#boster\n\n@suaramerdeka\n@hendrarprihadi\n@PemkotSmg\n\nhttps://t.co/8gGKfgPur8

# %% [markdown]
# ### <i>Crawling tweet</i> dari <i>username</i> spesifik
#
# Untuk mendapatkan <i>tweet</i> dari <i>username</i> spesifik, digunakan fungsi `get_users_tweets()` dengan parameter `user_id`. Pada contoh ini akan diambil 10 <i>tweet</i> terkini dari @Univ_Indonesia.

# %%
# 1. user lookup untuk mendapatkan ID
user = tweepy_client.get_user(username='univ_indonesia')
user_id = user.data.id
print("User ID untuk @univ_indonesia adalah:", user_id)

# 2. search tweet yang diposting oleh user ID tertentu
ui = tweepy_client.get_users_tweets(user_id, max_results=10)
print("Jumlah tweet dari @univ_indonesia yang berhasil didapatkan: {}.\n".format(len(ui.data)))
# Out:
# User ID untuk @univ_indonesia adalah: 74646907
# Jumlah tweet dari @univ_indonesia yang berhasil didapatkan: 10.

# %%
# contoh data
ui.data
# Out:
# [<Tweet id=1504766249964032001 text='Mahasiswa @Medicine_UI  raih juara di AMSA Internasional dan kompetisi fisiologi internasional di University of Health and Welfare, Jepang. Simak berita baik dari UI pekan ini dan dapatkan selengkapnya di https://t.co/QQb9GCdoNl. Selamat menikmati akhir pekan. https://t.co/SnZ2GYet58'>,
#  <Tweet id=1504009074592997376 text='Lokasi kampus UI terdapat di Salemba, Jakarta Pusat dan Depok, Jawa Barat. Sedangkan untuk penerimaan melalui jalur SNMPTN yang diselenggarakan LTMPT, pada tahun ini UI masuk ke wilayah DKI Jakarta dan Jawa Barat 😊 https://t.co/WFzRt5lZir'>,
#  <Tweet id=1503574424888348672 text='@aprilscnd @ui Halo,\nApabila terdapat kendala pada webmail UI Anda, silakan melapor ke DSTI UI melalui email ke support@ui.ac.id dengan melampirkan Nama, NPM, Program Studi, dan permasalahannya.'>,
#  <Tweet id=1502986716751474693 text='RT @ltmptofficial: H-4 PENUTUPAN REGISTRASI AKUN LTMPT UNTUK UTBK-SBMPTN 2022 \n\nHalo Calon Mahasiswa Indonesia!\n\nRegistrasi akun LTMPT untu…'>,
#  <Tweet id=1502980164778852352 text='RT @ltmptofficial: 10 HARI LAGI PENDAFTARAN UTBK-SBMPTN 2022! \n\nHalo Calon Mahasiswa Indonesia! \n\nPendaftaran UTBK-SBMPTN sudah di depan ma…'>,
#  <Tweet id=1502980035560771591 text='@ltmptofficial @xxwdrm Kalau diakhir namanya penyesalan ya, Min?'>,
#  <Tweet id=1502192475318145024 text='https://t.co/YknUdjr0qU'>,
#  <Tweet id=1502192468317839360 text='Berikut tata cara pelaksanaan ujian SIMAK UI Program Pascasarjana yang akan diselenggarakan pada Minggu, 13 Maret 2022.\n\nSemoga diberikan kelancaran dalam mengerjakan ujian. Tetap semangat dan jaga kesehatan! Sampai berjumpa di kampus perjuangan.\n\n#simakui #universitasindonesia https://t.co/N7xZnrUr6H'>,
#  <Tweet id=1501161740310298628 text='Selamat Hari Perempuan International kepada perempuan luar biasa di seluruh dunia! Tetaplah menjadi wanita yang kuat dan menginspirasi.\n\n#universitasindonesia https://t.co/rMLwJMryX6'>,
#  <Tweet id=1499587287214084096 text='@andong_ff @MuzakkiZulfikar Halo,\nDapat kami informasikan Universitas Indonesia saat ini menyediakan layanan legalisasi dokumen akademik secara daring. Informasi selengkapnya, silakan mengirimkan email  melalui email sipp@ui.ac.id'>]

# %% [markdown]
# ## Twitter Streaming API
#
# *Tweet* yang dikumpulkan menggunakan Twitter Streaming API merupakan data <i>tweet</i> yang bersifat <i>real time</i>. Langkah-langkah melakukan pengumpulan data dengan <i>Twitter Streaming API</i> adalah sebagai berikut:

# %% [markdown]
# ### Membuat StreamingClient
#
# Kelas `StreamingClient` akan memberikan informasi mengenai status <i>request data</i> Twitter yang kita cari. Pada kelas ini, terdapat dua fungsi yaitu fungsi `on_tweet()` yang mengembalikan data yang kita <i>request</i> dan fungsi `on_connection_error()` yang memberikan informasi jika koneksi gagal.
#
# Di dalam fungsi `on_tweet()`, akan didapatkan object Tweet dari Tweepy yang berisi data hasil <i>request</i>. Sementara itu, fungsi `on_connection_error()` memutus koneksi jika terdapat masalah <i>request</i>.

# %%
# import library
from tweepy import StreamingClient

class CustomStreamingClient(StreamingClient):
    def on_tweet(self, tweet):
        print(tweet.text)

    def on_connection_error(self):
        print("Connection error, stopping stream...")
        self.disconnect()

# %% [markdown]
# ### Membuat stream
#
# Kelas `CustomStreamingClient` digunakan untuk melakukan <i>request streaming</i> berdasarkan autorisasi dari token API yang kita miliki.
#
# Untuk standar parameter *filter* yang lain dapat dilihat di halaman <a href='https://developer.twitter.com/en/docs/tweets/filter-realtime/guides/basic-stream-parameters.html'>dokumentasi</a> Twitter.
#
# <b>Code 2</b>:

# %%
custom_stream = CustomStreamingClient(bearer_token)

# membuat rules untuk filter
custom_stream.add_rules(tweepy.StreamRule("ukraine"))
custom_stream.add_rules(tweepy.StreamRule("lang:en"))

custom_stream.filter()
# Out:
# Stream encountered HTTP error: 503
# Stream encountered HTTP error: 503
# Stream encountered HTTP error: 503
# @Credit_Agricole Crédit Agricole, votre argent peut financer de merveilleux projets de paix. Mais vous restez sur le marché russe, un pays qui a commencé et continue la guerre en Ukraine et tue des enfants ! Arrêtez toute activité commerciale en Russie. Fermez vos succursales. https://t.co/zMnMb4aPfh
# RT @justinsuntron: In 48 hours until 02/28/2022 21:00 GMT+8, Ukraine🇺🇦 #TRON accounts TEFccmfQ38cZS1DTZVhsxKVDckA8Y6VfCy has received total…
# RT @HoansSolo: Short summary of the military situation in Ukraine (March 22)
#
# Little change to overall operational picture:
#
# -pace of 🇷🇺 o…
# RT @CalltoActivism: BREAKING: VK, Russia's largest social media platform, has been hacked. Messages were sent to users that tell the true n…
# RT @mateo_tao: Another 67 surrender. These soldiers do not want to die for the regime in Kiew who has perpetuated a 8 year long genocidal w…
# podcast - @jheil interviews @RadioFreeTom about the Russian invasion of Ukraine, Putin, President Zelenskyy, Biden
# RT @DenisRogatyuk: #UkraineRussiaWar: “Zelensky, surrender! Stop taking drugs and go back to the stage!”
# A young woman crashed a news broad…
# @Independent Clown 🤡
# RT @From_Latam_: Donbass People (militias) fighting (defending their families and homes) against Azov battalions (Kiev th*gs backed by USA…
# RT @haveigotnews: Sajid Javid questions how people can reach the conclusion that Boris Johnson compared the situation in Ukraine to Brexit,…
# @Rotimk0 @Brendan_393 @Vanda39560230 @LPNH Thank you, However;
# The document is from March 1991, but Warsaw pact broke apart in Febuary 1991, freeing Poland and other countries from USSR.
# Of course, Belarus and Ukraine only separated in December, so that's still up in the air.
# Regardeless, thanks, this brings both sides up
# RT @sahouraxo: They cry crocodile tears over Ukraine, while they bomb and starve Yemen.
# RT @justinsuntron: In 24 hours until 02/27/2022 21:00 GMT+8, Ukraine🇺🇦 #TRON accounts TEFccmfQ38cZS1DTZVhsxKVDckA8Y6VfCy has received total…
# RT @dreslincourt: Guerre en Ukraine : Zelensky prêt à parler Donbass et Crimée avec Poutine!( AFP)
# Son armée est-elle détruite? La propagan…
# RT @truth_about_war: A protester in temporarily occupied #Kherson #Ukraine #StandWithUkraine #RussianOccupation #StopRussia #RussianWarCrim…
# RT @olgatokariuk: Everyone in Ukraine knows that this is what's going to happen to peaceful citizens if Russia is allowed to take more Ukra…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ichsan\Documents\proj\ams\tutorial3_Data Collection\Tutorial 3 - Data Collection.ipynb Cell 23' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/Tutorial%203%20-%20Data%20Collection.ipynb#ch0000023?line=3'>4</a> custom_stream.add_rules(tweepy.StreamRule("ukraine"))
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/Tutorial%203%20-%20Data%20Collection.ipynb#ch0000023?line=4'>5</a> custom_stream.add_rules(tweepy.StreamRule("lang:en"))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/Tutorial%203%20-%20Data%20Collection.ipynb#ch0000023?line=6'>7</a> custom_stream.filter()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py:745, in StreamingClient.filter(self, threaded, **params)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=742'>743</a>     return self._threaded_connect(method, endpoint, params=params)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=743'>744</a> else:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=744'>745</a>     self._connect(method, endpoint, params=params)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py:570, in StreamingClient._connect(self, method, endpoint, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=567'>568</a> self.session.headers["Authorization"] = f"Bearer {self.bearer_token}"
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=568'>569</a> url = f"https://api.twitter.com/2/tweets/{endpoint}/stream"
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=569'>570</a> super()._connect(method, url, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py:87, in BaseStream._connect(self, method, url, auth, params, headers, body)
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=83'>84</a> if not self.running:
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=84'>85</a>     break
# ---> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=86'>87</a> for line in resp.iter_lines(
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=87'>88</a>     chunk_size=self.chunk_size
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=88'>89</a> ):
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=89'>90</a>     if line:
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=90'>91</a>         self.on_data(line)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py:804, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=794'>795</a> """Iterates over the response data, one line at a time.  When
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=795'>796</a> stream=True is set on the request, this avoids reading the
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=796'>797</a> content at once into memory for large responses.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=797'>798</a>
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=798'>799</a> .. note:: This method is not reentrant safe.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=799'>800</a> """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=801'>802</a> pending = None
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=803'>804</a> for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=805'>806</a>     if pending is not None:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=806'>807</a>         chunk = pending + chunk
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py:760, in Response.iter_content.<locals>.generate()
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=757'>758</a> if hasattr(self.raw, 'stream'):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=758'>759</a>     try:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=759'>760</a>         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=760'>761</a>             yield chunk
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=761'>762</a>     except ProtocolError as e:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py:572, in HTTPResponse.stream(self, amt, decode_content)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=555'>556</a> """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=556'>557</a> A generator wrapper for the read() method. A call will block until
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=557'>558</a> ``amt`` bytes have been read from the connection or until the
#    (...)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=568'>569</a>     'content-encoding' header.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=569'>570</a> """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=570'>571</a> if self.chunked and self.supports_chunked_reads():
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=571'>572</a>     for line in self.read_chunked(amt, decode_content=decode_content):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=572'>573</a>         yield line
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=573'>574</a> else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py:764, in HTTPResponse.read_chunked(self, amt, decode_content)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=760'>761</a>     return
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=762'>763</a> while True:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=763'>764</a>     self._update_chunk_length()
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=764'>765</a>     if self.chunk_left == 0:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=765'>766</a>         break
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py:694, in HTTPResponse._update_chunk_length(self)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=691'>692</a> if self.chunk_left is not None:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=692'>693</a>     return
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=693'>694</a> line = self._fp.fp.readline()
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=694'>695</a> line = line.split(b";", 1)[0]
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=695'>696</a> try:
#
# File C:\ProgramData\Anaconda3\lib\socket.py:669, in SocketIO.readinto(self, b)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=666'>667</a> while True:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=667'>668</a>     try:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=668'>669</a>         return self._sock.recv_into(b)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=669'>670</a>     except timeout:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=670'>671</a>         self._timeout_occurred = True
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# objek custom stream
custom_stream

# %%
# cek rules yang sudah di-add
custom_stream.get_rules()
# Out:
# Response(data=[StreamRule(value='ukraine', tag=None, id='1506197809451900931')], includes={}, errors=[], meta={'sent': '2022-03-22T09:16:46.299Z', 'result_count': 1})

# %%
# menghapus stream rules
custom_stream.delete_rules(ids='1505082423637266432')
# Out:
# Response(data=None, includes={}, errors=[{'errors': [{'parameters': {}, 'message': 'Rule does not exist'}], 'title': 'Invalid Request', 'detail': 'One or more parameters to your request was invalid.', 'type': 'https://api.twitter.com/2/problems/invalid-request'}], meta={'sent': '2022-03-22T09:16:51.443Z', 'summary': {'deleted': 0, 'not_deleted': 1}})

# %%
custom_stream.get_rules()
# Out:
# Response(data=[StreamRule(value='ukraine', tag=None, id='1506197809451900931')], includes={}, errors=[], meta={'sent': '2022-03-22T09:16:54.153Z', 'result_count': 1})

# %% [markdown]
# ## Data User - Twitter
#
# Selain data *tweet*, data profil akun Twitter juga dapat didapatkan. Karena sebelumnya kita telah mengambil data tweet menggunakan *bearer token*, di tahap ini kita akan mencoba autentikasi user menggunakan token. Jika ingin mencoba mengambil data user dengan menggunakan *bearer token*, teman-teman bisa mengikuti sampel kode <a href="https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/User-Lookup/get_users_with_bearer_token.py">ini</a>.

# %%
consumer_key = "" # diisi
consumer_secret = "" # diisi

# %% [markdown]
# <b>Code 3</b>

# %%
from requests_oauthlib import OAuth1Session
# field user yg ingin diambil, referensi: https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/user
fields = "created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld"
params = {"usernames": "NajwaShihab,gojektech", "user.fields": fields}
request_token_url = "https://api.twitter.com/oauth/request_token"
oauth = OAuth1Session(consumer_key, client_secret=consumer_secret)
fetch_response = oauth.fetch_request_token(request_token_url)

# %%
# objek response
fetch_response
# Out:
# {'oauth_token': 'b-wqAgAAAAABaVF7AAABf7DqS1Q',
#  'oauth_token_secret': 'gKr0EQREr7lXnCDCgkXHjR8E1kE3O3s4',
#  'oauth_callback_confirmed': 'true'}

# %%
resource_owner_key = fetch_response.get("oauth_token")
resource_owner_secret = fetch_response.get("oauth_token_secret")

# %%
# authorisasi
base_authorization_url = "https://api.twitter.com/oauth/authorize"
authorization_url = oauth.authorization_url(base_authorization_url)
print("Please go here and authorize: %s" % authorization_url)
verifier = input("Paste the PIN here: ")
# Out:
# Please go here and authorize: https://api.twitter.com/oauth/authorize?oauth_token=b-wqAgAAAAABaVF7AAABf7DqS1Q

# %%
# Get the access token
access_token_url = "https://api.twitter.com/oauth/access_token"
oauth = OAuth1Session(
    consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=resource_owner_key,
    resource_owner_secret=resource_owner_secret,
    verifier=verifier,
)
oauth_tokens = oauth.fetch_access_token(access_token_url)

access_token = oauth_tokens["oauth_token"]
access_token_secret = oauth_tokens["oauth_token_secret"]

# make the request
oauth = OAuth1Session(
    consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=access_token,
    resource_owner_secret=access_token_secret,
)

# %%
response = oauth.get(
    "https://api.twitter.com/2/users/by", params=params
)

if response.status_code != 200:
    raise Exception(
        "Request returned an error: {} {}".format(response.status_code, response.text)
    )

print("Response code: {}".format(response.status_code))

json_response = response.json()
# Out:
# Response code: 200

# %%
# objek response
json_response
# Out:
# {'data': [{'name': 'Najwa Shihab',
#    'description': 'Founder https://t.co/1H5VBxjbYU\nTwitter: @narasitv',
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/839298349148717056/yEE35xbx_normal.jpg',
#    'created_at': '2008-10-22T21:15:07.000Z',
#    'location': 'ÜT: -6.292607,106.821193',
#    'verified': True,
#    'protected': False,
#    'id': '16912985',
#    'public_metrics': {'followers_count': 8074446,
#     'following_count': 487,
#     'tweet_count': 25836,
#     'listed_count': 3019},
#    'url': 'https://t.co/Yg2rg6isix',
#    'username': 'NajwaShihab',
#    'entities': {'url': {'urls': [{'start': 0,
#        'end': 23,
#        'url': 'https://t.co/Yg2rg6isix',
#        'expanded_url': 'http://www.narasi.tv',
#        'display_url': 'narasi.tv'}]},
#     'description': {'urls': [{'start': 8,
#        'end': 31,
#        'url': 'https://t.co/1H5VBxjbYU',
#        'expanded_url': 'http://Narasi.TV',
#        'display_url': 'Narasi.TV'}],
#      'mentions': [{'start': 41, 'end': 50, 'username': 'narasitv'}]}}},
#   {'name': 'Gojek Tech',
#    'description': "@GojekIndonesia's product + engineering division. Crafting SE Asia's fastest growing Super App. 1100x growth in 36 months, now serving 200M+ orders per month.🖖",
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/1153975468812406785/ONvxKr_G_normal.jpg',
#    'created_at': '2015-12-07T06:52:53.000Z',
#    'location': 'BLR. GGN. JKT. SG.',
#    'verified': True,
#    'protected': False,
#    'id': '4483368134',
#    'public_metrics': {'followers_count': 19525,
#     'following_count': 149,
#     'tweet_count': 2317,
#     'listed_count': 114},
#    'pinned_tweet_id': '1480781930547367945',
#    'url': 'https://t.co/c1e8IMLiW6',
#    'username': 'gojektech',
#    'entities': {'url': {'urls': [{'start': 0,
#        'end': 23,
#        'url': 'https://t.co/c1e8IMLiW6',
#        'expanded_url': 'http://www.gojek.io',
#        'display_url': 'gojek.io'}]},
#     'description': {'mentions': [{'start': 0,
#        'end': 15,
#        'username': 'GojekIndonesia'}]}}}]}

# %% [markdown]
# # Data Collection - Twitter (Twint)
#
# Selain menggunakan Tweepy, pengumpulan data <i>tweet</i> dapat juga dilakukan dengan menggunakan <i>library</i> <a href='https://github.com/twintproject/twint'>Twint</a>. Perbedaan <i>library</i> ini dengan Tweepy adalah tidak membutuhkan <i>access token</i> Twitter API.
#
# Berikut merupakan contoh penggunaan Twint dalam melakukan <i>crawling tweet</i>:

# %%
# import library
import twint
import nest_asyncio

nest_asyncio.apply()

# %%
# need time about 10-15 mins

c = twint.Config()
keyword = 'goto'
c.Search = keyword # masukkan kata kunci
c.Since = '2022-03-15 00:00:00'
c.Until = '2022-03-15 23:59:59' 
c.Store_csv = True
c.Output = '{}.csv'.format(keyword)
c.Hide_output = True

twint.run.Search(c)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# explore data 
df_goto = pd.read_csv('goto.csv')
df_goto.info()
df_goto.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10989 entries, 0 to 10988
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               10989 non-null  int64
#  1   conversation_id  10989 non-null  int64
#  2   created_at       10989 non-null  object
#  3   date             10989 non-null  object
#  4   time             10989 non-null  object
#  5   timezone         10989 non-null  int64
#  6   user_id          10989 non-null  int64
#  7   username         10989 non-null  object
#  8   name             10989 non-null  object
#  9   place            3 non-null      object
#  10  tweet            10989 non-null  object
#  11  language         10989 non-null  object
#  12  mentions         10989 non-null  object
#  13  urls             10989 non-null  object
#  14  photos           10989 non-null  object
#  15  replies_count    10989 non-null  int64
#  16  retweets_count   10989 non-null  int64
#  17  likes_count      10989 non-null  int64
#  18  hashtags         10989 non-null  object
#  19  cashtags         10989 non-null  object
#  20  link             10989 non-null  object
#  21  retweet          10989 non-null  bool
#  22  quote_url        609 non-null    object
#  23  video            10989 non-null  int64
#  24  thumbnail        1050 non-null   object
#  25  near             0 non-null      float64
#  26  geo              0 non-null      float64
#  27  source           0 non-null      float64
#  28  user_rt_id       0 non-null      float64
#  29  user_rt          0 non-null      float64
#  30  retweet_id       0 non-null      float64
#  31  reply_to         10989 non-null  object
#  32  retweet_date     0 non-null      float64
#  33  translate        0 non-null      float64
#  34  trans_src        0 non-null      float64
#  35  trans_dest       0 non-null      float64
# dtypes: bool(1), float64(10), int64(8), object(17)
# memory usage: 2.9+ MB
#                     id      conversation_id  \
# 0  1503883736345366530  1503883736345366530
# 1  1503883692493606915  1503680965595451395
# 2  1503883672705028099  1503883424192421893
# 3  1503883640983650307  1503883640983650307
# 4  1503883626114859009  1503883626114859009
#
#                                   created_at        date      time  timezone  \
# 0  2022-03-16 06:59:58 SE Asia Standard Time  2022-03-16  06:59:58       700
# 1  2022-03-16 06:59:47 SE Asia Standard Time  2022-03-16  06:59:47       700
# 2  2022-03-16 06:59:43 SE Asia Standard Time  2022-03-16  06:59:43       700
# 3  2022-03-16 06:59:35 SE Asia Standard Time  2022-03-16  06:59:35       700
# 4  2022-03-16 06:59:31 SE Asia Standard Time  2022-03-16  06:59:31       700
#
#                user_id         username                name place  ... geo  \
# 0  1376072002298019849          14106_s  ぷ。 ฅ(ᵔᴥᵔ)ฅやわやわ🚶‍♀️   NaN  ... NaN
# 1   992932185144348672  mowchan_mowchan            MOW/元保育者   NaN  ... NaN
# 2  1227999980654407680  stemthebleeding     STEMtheBleeding   NaN  ... NaN
# 3   918325280950726656    osanpo_hiyoko            tekupiyo   NaN  ... NaN
# 4  1495109550596190212          goto1ri                  ☁️   NaN  ... NaN
#
#   source user_rt_id user_rt retweet_id  \
# 0    NaN        NaN     NaN        NaN
# 1    NaN        NaN     NaN        NaN
# 2    NaN        NaN     NaN        NaN
# 3    NaN        NaN     NaN        NaN
# 4    NaN        NaN     NaN        NaN
#
#                                                                                  reply_to  \
# 0                                                                                      []
# 1  [{'screen_name': 'LugcNzz4CPY0roF', 'name': 'たまご 6y&2y', 'id': '1264785023137271808'}]
# 2       [{'screen_name': 'fit__feminist', 'name': 'Abadass Mom Bod', 'id': '4597876452'}]
# 3                                                                                      []
# 4                                                                                      []
#
#    retweet_date  translate trans_src trans_dest
# 0           NaN        NaN       NaN        NaN
# 1           NaN        NaN       NaN        NaN
# 2           NaN        NaN       NaN        NaN
# 3           NaN        NaN       NaN        NaN
# 4           NaN        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# wordcloud tweet goto

# import library
import nltk
from nltk.tokenize import word_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
stop_factory = StopWordRemoverFactory()
stopwords = stop_factory.get_stop_words()

from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = ' '.join(df_goto['tweet'].unique().tolist())

# create and generate a word cloud image:
wordcloud = WordCloud(stopwords=stopwords, max_words=100, background_color="white").generate(text)

# display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Data Collection - Twecoll
#
# Pada tutorial kali ini, akan dibahas tentang langkah-langkah untuk mengetahui <i>friends-of-friends network</i>. Analisis <i>friends-of-friends</i> merupakan analisis yang dilakukan pada
# jaringan media sosial yang bertujuan untuk mengetahui jaringan pertemanan. Pada tutorial
# ini, akan dilakukan pengumpulan data jaringan <i>friends-of-friends</i> dari Twitter dengan
# menggunakan Twecoll.
#
# Langkah-langkah untuk untuk mengambil data pertemanan menggunakan Twecoll adalah
# sebagai berikut:
# 1. Masuk ke direktori dari twecoll dan eksekusi perintah berikut:<br>
# ```
# python twecoll init <USERNAME_TWITTER_TARGET>
# ```
# Setelah selesai akan dihasilkan berkas .dat dengan format <USERNAME_TWITTER_TARGET>.dat
#
# 2. Ketika baru dijalankan pertama kali, maka program akan meminta <i>consumer secret</i> dan
# <i>consumer key</i>. Masukkan <i>consumer secret</i> dan <i>consumer key</i> masing-masing.
#
# 3. Setelah terverifikasi, program akan mengarahkan ke <i>browser</i> yang berisi PIN. Berikut
# adalah contoh halaman yang menampilkan PIN.
# <img src='images/image2.png'></img>
# Masukkan PIN yang ditampilkan di <i>browser</i> ke dalam program.
#
# 4. Setelah selesai, eksekusi perintah berikut:
# ```
# python twecoll fetch <USERNAME_TWITTER_TARGET>
# ```
# Proses ini akan menghasilkan suatu berkas berekstensi .f di dalam folder fdat yang
# berisi daftar <i>user id</i> pada jaringan <i>friends-of-friends</i>. Untuk mengunduh data ini,
# diperlukan waktu sekitar 5-6 jam (bisa lebih lama, tergantung jumlah
# <i>follower</i>/<i>following</i> target). Hal ini disebabkan oleh <i>rate limit</i> dari Twitter API yang hanya memberikan akses data sebanyak 15 <i>requests</i> per 15 menit.
#
# 5. Setelah selesai, eksekusi perintah berikut:
# ```
# python twecoll edgelist <USERNAME_TWITTER_TARGET>
# ```
# Perintah tersebut akan membentuk daftar <i>edge</i> dari daftar pertemanan yang sudah
# disimpan dalam folder fdat. Keluaran dari perintah ini adalah berupa berkas .gml
# dengan format <USERNAME_TWITTER_TARGET>.gml. Berikut adalah contoh isi berkas
# .gml dari <i>username</i> target “najwashihab”
# <img src='images/image4.png'></img>
#
# Untuk dapat melihat visualisasi antar <i>nodes</i>, berkas .gml pada langkah 5 dapat dibuka dengan menggunakan <i>graph processing tools</i> seperti Gephi atau dengan Python <i>library</i>, misalnya NetworkX dan igraph. Berikut adalah cara memvisualisikan berkas .gml pada Gephi:
#
# 1. Saat membuka file .gml untuk pertama kali, akan muncul tampilan seperti ini
# <img src='images/image3.png'></img>
#
# 2. Mengatur layout
# Graf yang ditunjukkan tidak beraturan dan susah untuk dianalisis. Di dalam Gephi
# terdapat beberapa <i>plugins</i> yang dapat digunakan untuk merepresentasikan kembali graf
# menjadi lebih terkelompok dan membuat <i>node</i> menjadi mudah untuk dilihat. <i>Layout</i>
# dapat diakses pada <i>box</i> pada pojok kiri bawah dari layar Gephi.
# <img src='images/image6.png'></img>
#
# 3. Jika Anda klik dropdown `---Choose Layout`, maka akan muncul beberapa pilihan algoritma yang dapat dipilih seperti Force Atlas, Yifan Hu, dan lain-lain. Coba Anda pilih algoritma Force Atlas lalu <i>click</i> `Run`. Setelah beberapa saat lalu klik `Stop`, maka graf akan bergerak.
# <img src='images/image5.png'></img>
#
# 4. Anda dapat menginstal beberapa plugins tambahan untuk visualisasi layout dengan
# masuk ke dalam <i>Tools</i> lalu <i>Plugins</i>.
#
# <i>Disclaimer</i>: Tidak ada tugas visualisasi <i>network</i> yang diujikan pada tutorial ini, namun hal tersebut akan berguna untuk <i>midterm project</i>.

# %% [markdown]
# # Data Collection - Instagram
#
# Salah satu cara untuk mengambil data dari Instagram adalah dengan menggunakan <i>library</i> Instaloader. Sebelum menggunakan <i>library</i> tersebut, kita perlu login terlebih dahulu.

# %%
from instaloader import Instaloader

loader = Instaloader()
user = '' # diisi
pwd = '' # diisi
loader.login(user, pwd)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'utf-8', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)

# %% [markdown]
# Data yang akan kita ambil dalam tutorial ini adalah data profil, postingan, komentar, dan balasan komentar.

# %% [markdown]
# ## Data Profil - Instagram
#
# Profil dari sebuah akun dapat dicari dengan kita mengetahui <i>username</i> atau id dari akun tersebut. Dokumentasi terkait representasi objek profil dapat diakses pada halaman <a href="https://instaloader.github.io/module/structures.html?highlight=p#instaloader.p">ini</a>.
#
# Pada tutorial ini, kita akan mencoba mengambil data profil <a href="https://www.instagram.com/najwashihab/">Mba Nana</a>.

# %%
from instaloader import Profile

profile = Profile.from_username(loader.context, 'najwashihab')
# objek profile
profile
# Out:
# <Profile najwashihab (48294511)>

# %% [markdown]
# Sebuah objek profil memiliki beberapa properti, seperti `userid`, `username`, `is_private`, dsb. Kita akan menyimpan data profil ke sebuah pandas dataframe.

# %%
import pandas as pd
pd.set_option('max_colwidth', 1000)

df_profile = pd.DataFrame({
    'userid': [p.userid],
    'username': [p.username],
    'is_private': [p.is_private],
    'mediacount': [p.mediacount],
    'igtvcount': [p.igtvcount],
    'followers': [profile.followers],
    'followees': [profile.followees],
    'external_url': [profile.external_url],
    'is_business_account': [profile.is_business_account],
    'business_category_name': [profile.business_category_name],
    'biography': [profile.biography],
    'full_name': [profile.full_name],
    'has_public_story': [profile.has_public_story],
    'is_verified': [profile.is_verified],
    'profile_pic_url': [profile.profile_pic_url]
}) 

df_profile
# Out:
#      userid     username  is_private  mediacount  igtvcount  followers  \
# 0  48294511  najwashihab       False        4153       1140   21214573
#
#    followees           external_url  is_business_account  \
# 0        787  http://www.narasi.tv/                False
#
#   business_category_name  \
# 0                   None
#
#                                                                                                                   biography  \
# 0  Founder Narasi @narasi.tv @narasinewsroom\nWatch more on www.narasi.tv also YouTube NajwaShihab, Narasi, NarasiNewsroom.
#
#       full_name  has_public_story  is_verified  \
# 0  Najwa Shihab              True         True
#
#                                                                                                                                                                                                                                                                                   profile_pic_url
# 0  https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/69404594_447731939153837_7938163589615976448_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=S4qCxqRK03IAX8fxXha&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9JFvM136FEhWOXJGZWvjpg7m5VkFmwa35PRMVsrsucUw&oe=6240D2D5&_nc_sid=a9513d

# %% [markdown]
# ## Data Postingan - Instagram

# %% [markdown]
# Data postingan dari sebuah akun dapat diambil dengan menjalankan fungsi `get_posts()`. Data yang dikembalikan berupa iterator. Dokumentasi terkait objek postingan dapat diakses melalui halaman <a href="https://instaloader.github.io/module/structures.html?highlight=profile#instaloader.Post">ini</a>.
#
# Kali ini, kita akan mengambil 5 postingan terbaru dari akun <a href="https://www.instagram.com/najwashihab/">Mba Nana</a>.

# %%
posts = profile.get_posts()
# iterator posts
posts

# %%
counter = 0
df_posts = pd.DataFrame()
for p in posts:
    if counter == 5:
        break
    df_posts = df_posts.append({
        'shortcode': p.shortcode,
        'mediaid': p.mediaid,
        'title': p.title,
        'owner_username': p.owner_username,
        'date_local': p.date_local,
        'date_utc': p.date_utc,
        'url': p.url,
        'typename': p.typename,
        'mediacount': p.mediacount,
        'caption': p.caption,
        'caption_hashtags': p.caption_hashtags,
        'caption_mentions': p.caption_mentions,
        'tagged_users': p.tagged_users,
        'is_video': p.is_video,
        'video_url': p.video_url,
        'video_view_count': p.video_view_count,
        'video_duration': p.video_duration,
        'likes': p.likes,
        'comments': p.comments
    }, ignore_index=True)
    counter += 1
df_posts
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    caption  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Yakin mau pemilu ditunda? Coba dengerin jawaban @bivitrisusanti @burhanuddinmuhtadi dan @zainalarifinmochtar\n\n| Catatan Najwa\n#CatatanNajwa #Narasi #JadiPaham #PemiluDitunda
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            @klubbukunarasi #MingguPuisi untuk kamu yang merasa ragu dan takut.\n\nTangan\nOleh Ni Made Purnama Sari @purnamarisa_ \n\n"Tanganku, apa yang selama ini sudah kau buat? Mengapa semua tidak bisa lagi kau ingat? Mari ke sini kita baca buku lagi..."\n\nDari buku kumpulan puisi Kawitan.\n\n#klubbukunarasi #CatatanNajwa
# 2  24 Juli 2022 nanti saya mau ajak teman2 lari. Ajakan ini terutama untuk yang belum pernah (bahkan gak pernah mikir) ikut event lari. Yang terakhir lari jaman SD waktu main kasti. Yang terlanjur mengasosiasikan lari dgn trauma hukuman.\n\nSemua di atas itu deskripsi perasaan saya tahun lalu. Tapi seperti banyak hal lain, pandemi mengubah dan membuat kita mencoba hal baru. Ada yang jadi suka tanaman, rajin sepedaan, atau yang seperti saya, lelarian. \n\nKenapa lari? Mungkin karena lari sepenuhnya mengandalkan kekuatan fisik dan pikiran. Tidak perlu alat dan ragam cara. Ketika pandemi memaksa kita kehilangan banyak pilihan, lari adalah cara saya memastikan tetap punya daya. Niat, target, rencana, eksekusi, kontrol, semua ada di tangan (dan kaki) saya.\n\nKarena lari bukan semata urusan jarak atau pace waktu. Tapi perasaan tuntas bisa menyelesaikan sesuatu. Saya gak bilang lari itu gampang dan bisa cepat lancar. Sampai sekarang saya masih jauh dari target2 yang saya idamkan.\n\nYang sa...
# 3  @rahasiagadis I accept your challenge! \n\nMitos itu berkata, pelecehan hanya terjadi pada perempuan yang sedang sendiri, malam hari, di tempat sepi dan berbusana mini.\n\nFaktanya? Lokasi yang paling banyak menjadi latar terjadinya pelecehan seksual adalah jalan umum, transportasi publik, lalu sekolah dan kampus. Kasusnya terjadi paling banyak di siang hari dan jenis pakaian yang dikenakan korban sama sekali bukan faktor signifikan. \n\nSetiap perempuan rentan terhadap perlecehan seksual. Setop menyalahkan korban. Yang bersalah adalah pelaku tidak pernah korban. \n\nTiap kita pantas dan berharga.\n\nUntuk merayakan Hari Perempuan Internasional dan memberi dukungan kekuatan kepada sesama perempuan, yuk ikut posting foto kamu dengan post-it bertulisan #KamuBerharga\n\nUntuk setiap foto yang diunggah menggunakan #KamuBerhargaRG sampai 15 Maret 2022, @rahasiagadis akan menyumbangkan Rp 10,000 ke Yayasan Kemanusiaan untuk Indonesia dalam program Pundi Perempuan untuk mendukung para gad...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                             Masih ingat dengan kasus pelecehan seksual di KPI? Sejak ramai di September 2021 lalu, hingga kini kasus dari korban pria berinisial MS ini belum juga menemui titik terang.\n\nApa yang terjadi setelah berita itu viral? Bagaimana MS menjalani kehidupannya sehari-hari dalam kondisi yang masih trauma?\n\nSimak penuturan MS dalam Surat Untuk Najwa episode "Blak-blakan MS, Korban Pelecehan Seksual KPI: Saya Diminta Tidak Bicara" di channel Youtube Najwa Shihab atau kunjungi web narasi.tv\n\n| Surat untuk Najwa\n\n#SuratUntukNajwa #KasusPelecehanSeksual #Narasi #JadiPaham
#
#                                               caption_hashtags  \
# 0             [catatannajwa, narasi, jadipaham, pemiluditunda]
# 1                  [minggupuisi, klubbukunarasi, catatannajwa]
# 2                           [pocarisweatrun2022, catatannajwa]
# 3      [kamuberharga, kamuberhargarg, kamuberhargarg, iwd2022]
# 4  [suratuntuknajwa, kasuspelecehanseksual, narasi, jadipaham]
#
#                                                                     caption_mentions  \
# 0                          [bivitrisusanti, burhanuddinmuhtadi, zainalarifinmochtar]
# 1                                                     [klubbukunarasi, purnamarisa_]
# 2                                                                                 []
# 3  [rahasiagadis, rahasiagadis, meutyahafid, widyacatlady, housniati, melanieputria]
# 4                                                                                 []
#
#    comments          date_local            date_utc  is_video     likes  \
# 0     368.0 2022-03-22 11:38:44 2022-03-22 04:38:44       1.0   15476.0
# 1      64.0 2022-03-20 18:58:50 2022-03-20 11:58:50       1.0   10685.0
# 2     613.0 2022-03-19 11:49:36 2022-03-19 04:49:36       0.0  222082.0
# 3     856.0 2022-03-08 13:41:10 2022-03-08 06:41:10       0.0  233460.0
# 4     950.0 2022-03-07 20:46:56 2022-03-07 13:46:56       1.0   81247.0
#
#    mediacount       mediaid owner_username    shortcode  \
# 0         1.0  2.799310e+18    najwashihab  CbZJgf6DlKU
# 1         1.0  2.798082e+18    najwashihab  CbUyPw2gVy9
# 2         2.0  2.797142e+18    najwashihab  CbRciqgvpYR
# 3         1.0  2.789226e+18    najwashihab  Ca1UkNqDigc
# 4         1.0  2.788715e+18    najwashihab  CazgTXxDzq5
#
#                                                                            tagged_users  \
# 0                  [matanajwa, zainalarifinmochtar, burhanuddinmuhtadi, bivitrisusanti]
# 1                                                [najwashihab, sastragpu, purnamarisa_]
# 2  [ridwankamil, narasi.tv, melanieputria, agusprayogo21, pocarisportid, fukazawa_wina]
# 3                                 [rahasiagadis, meutya_hafid, widyacatlady, housniati]
# 4                                                                                    []
#
#   title      typename  \
# 0          GraphVideo
# 1          GraphVideo
# 2  None  GraphSidecar
# 3  None    GraphImage
# 4          GraphVideo
#
#                                                                                                                                                                                                                                                                                                                                                                           url  \
# 0                                               https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-15/276982170_105427975394966_7322320596808346047_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat
nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=hMW5tAppYwEAX8ot93A&edm=ALQROFkBAAAA&vs=666494377794721_3444463745&_nc_vs=HBksFQAYJEdJQ1dtQUIwV0dvTDlUTUJBRUFkRHcyelN5VkpidlZCQUFBRhUAAsgBABUAGCRHSmZrZEJEeExWWkFVUG9DQVBkZGpLWG9zRUpSYnZWQkFBQUYVAgLIAQAoABgAGwGIB3VzZV9vaWwBMRUAACbonfbGq6fuPxUCKAJDMywXQFfxBiTdLxsYEmRhc2hfYmFzZWxpbmVfMV92MREAdewHAA%3D%3D&ccb=7-4&oe=623BBAD6&oh=00_AT8KQRbNgJRBJhUIOoSDZY68MxrN0lmLEZui8bB5cRLpMA&_nc_sid=30a2ef
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  None
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  None
# 4                                                                                                                                                                                                                                                                                                                                                    https://instagram.fbdo1-2.fna.fbcdn.net/v/t50.2886-16/275513964_1103659930419874_1523745697042686466_n.mp4?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=yKCNcKwEeDgAX-oAvv1&edm=AAuNW_gBAAAA&ccb=7-4&oe=623BE95B&oh=00_AT_91uEYxegK4N6tfETqqBDenEKVBgzuIKhIDqH8apjKmA&_nc_sid=498da5
#
#   video_view_count
# 0         190073.0
# 1         112020.0
# 2             None
# 3             None
# 4           813959

# %% [markdown]
# ## Data Komentar - Instagram
# Sebuah postingan dapat memiliki komentar. Data terkait komentar dapat diambil dengan menjalankan fungsi `get_comments()`. Fungsi tersebut mengembalikan objek iterator. Dokumentasi terkait objek komentar dapat diakses melalui halaman <a href="https://instaloader.github.io/module/structures.html?highlight=profile#instaloader.PostComment">ini</a>.
#
# Kita akan mengambil 5 komentar dari postingan terbaru dari akun <a href="https://www.instagram.com/najwashihab/">Mba Nana</a>.

# %%
from instaloader import Post
# mendapatkan objek postingan dengan menggunakan shortcode
post = Post.from_shortcode(loader.context, df_posts.loc[0]['shortcode'])
# objek postingan
post
# Out:
# <Post CbZJgf6DlKU>

# %%
# iterator comments
comments = post.get_comments()
comments

# %%
def get_comment_answers(answers):
    res = []
    for a in answers:
        res.append({
            'created_at_utc': a.created_at_utc,
            'id': a.id,
            'likes_count': a.likes_count,
            'owner_username': a.owner.username,
            'text': a.text
        })
    return res

counter = 0
df_comments = pd.DataFrame()
for c in comments:
    if counter == 5:
        break
    df_comments = df_comments.append({
        'answers': get_comment_answers(c.answers),
        'created_at_utc': c.created_at_utc,
        'id': c.id,
        'likes_count': c.likes_count,
        'owner_username': c.owner.username,
        'text': c.text
    }, ignore_index=True)
    counter += 1
    
df_comments
# Out:
#   answers      created_at_utc            id  likes_count owner_username  \
# 0      [] 2022-03-22 04:51:05  1.794595e+16          0.0    __albernn__
# 1      [] 2022-03-22 09:32:50  1.828602e+16          0.0    budhianto28
# 2      [] 2022-03-22 04:51:05  1.794595e+16          0.0    __albernn__
# 3      [] 2022-03-22 09:32:50  1.828602e+16          0.0    budhianto28
# 4      [] 2022-03-22 04:51:05  1.794595e+16          0.0    __albernn__
#
#                                                                          text
# 0                                               bujug pada promosi komennya:v
# 1  Tdk usah ditunda deh, lha wong Presidennya aja tdk mau kl diperpanjang ...
# 2                                               bujug pada promosi komennya:v
# 3  Tdk usah ditunda deh, lha wong Presidennya aja tdk mau kl diperpanjang ...
# 4                                               bujug pada promosi komennya:v

# %% [markdown]
# # Data Collection - Linkedin
#
# Salah satu cara untuk mendapatkan data dari Linkedin adalah dengan melakukan <i>scraping</i> menggunakan <i>library</i> Selenium. Jadi, sebelum memulai, teman-teman perlu mengunduh chromedriver sesuai dengan versi Chrome dan OS yang Anda gunakan. Chromedriver dapat diunduh pada halaman <a href="https://chromedriver.chromium.org/downloads">berikut</a>.
#
# Berikut merupakan contoh kode yang digunakan untuk mengambil data profil suatu akun Linkedin.

# %%
# import library
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import os
import time

driver_path = 'chromedriver.exe'

# %%
# functions
def scroll(height):
    driver.execute_script('window.scrollTo(0, {})'.format(height))


def get_single_element(xpath):
    WebDriverWait(driver, 3).until(
        EC.presence_of_element_located((By.XPATH, xpath)))
    return driver.find_element_by_xpath(xpath)

def fill_in(xpath, text):
    elem = get_single_element(xpath)
    elem.send_keys(text)


def get_multiple_element(xpath):
    WebDriverWait(driver, 3).until(
        EC.presence_of_all_elements_located((By.XPATH, xpath)))
    return driver.find_elements_by_xpath(xpath)


def get_text(element):
    return driver.execute_script('return arguments[0].innerText;', element)


def get_content(xpath):
    return get_text(get_single_element(xpath))


def open_driver(url):
    global driver
    driver = webdriver.Chrome(driver_path)
    driver.get(url)
    time.sleep(1)


def get_soup(url, verify=True):
    page = requests.get(url, verify=verify)
    soup = BeautifulSoup(page.content)
    return soup

# %%
# login
link = 'https://www.linkedin.com/login/in?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin'
open_driver(link)
xpath = '//input[@id="username"]'
fill_in(xpath, '') # diisi
xpath = '//input[@id="password"]'
fill_in(xpath, '') # diisi
xpath = '//button[@class="btn__primary--large from__button--floating"]'
get_single_element(xpath).click()
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   return driver.find_element_by_xpath(xpath)

# %%
link = 'https://www.linkedin.com/in/jerome-polin-sijabat-b0241247/'
driver.get(link)

# %%
xpath = '//h1[@class="text-heading-xlarge inline t-24 v-align-middle break-words"]'
name = get_content(xpath)
name
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   return driver.find_element_by_xpath(xpath)
# 'Jerome Polin Sijabat'

# %%
xpath = '//div[@class="display-flex ph5 pv3"]'
try:
    about = get_content(xpath)
except:
    about = None
    print("No description")
about
# Out:
# No description

# %%
xpath = '//div[@id="experience"]/../div[3]/ul/*'
experiences = get_multiple_element(xpath)
experiences
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   return driver.find_elements_by_xpath(xpath)
# [<selenium.webdriver.remote.webelement.WebElement (session="34f281f40fe031f547350f6980b4be00", element="a6a610f6-691b-4065-ac34-7b26438177d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="34f281f40fe031f547350f6980b4be00", element="479438c2-28f1-4d47-b2b5-e1b73b6b98f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="34f281f40fe031f547350f6980b4be00", element="2518607e-cea1-40ae-814b-30d05030a96b")>]

# %%
arr_exp_raw = [] 
for exp in experiences:
    arr_exp_raw.append(get_text(exp))

# %%
arr_exp_raw
# Out:
# ['Co-Founder\nCo-Founder\nMenantea · Permanent\nMenantea · Permanent\nApr 2021 - Present · 1 yr\nApr 2021 - Present · 1 yr\nJakarta, Indonesia\nJakarta, Indonesia\nMenantea, a modern fusion tea brand in Indonesia, was founded 5 people with their each expertise on FnB industry and digital marketing. 3 of which is Hendy Setiono (founder of BabaRafi Enterprise), Sylvia Surya (founder of Kopisoe), and Bisma Adi Putra (F&B Consultant Masakin Group), and the remaining 2 is manager-talent brothers: Jehian Panangian Sijabat and Jerome Polin Sijabat. With its various tea menus, like modern fruit tea, cheese cream tea, and more, Menantea wants to revolutionize how Indonesians enjoy tea beverages.\n\nWith our exclusive FnB technology, and strong digital marketing side, Menantea aspire to be one of the fastest growing tea brand, gaining 200k+ followers on instagram, and 35 store openings (10 Cities in Indonesia), in less than 1 month since its grand opening.\nMenantea, a modern fusion tea brand in Indonesia, was founded 5 people with their each expertise on FnB industry and digital marketing. 3 of which is Hendy Setiono (founder of BabaRafi Enterprise), Sylvia Surya (founder of Kopisoe), and Bisma Adi Putra (F&B Consultant Masakin Group), and the remaining 2 is manager-talent brothers: Jehian Panangian Sijabat and Jerome Polin Sijabat. With its various tea menus, like modern fruit tea, cheese cream tea, and more, Menantea wants to revolutionize how Indonesians enjoy tea beverages. With our exclusive FnB technology, and strong digital marketing side, Menantea aspire to be one of the fastest growing tea brand, gaining 200k+ followers on instagram, and 35 store openings (10 Cities in Indonesia), in less than 1 month since its grand opening.',
#  'Founder\nFounder\nMantappu Corp · Permanent\nMantappu Corp · Permanent\nDec 2017 - Present · 4 yrs 4 mos\nDec 2017 - Present · 4 yrs 4 mos\nTokyo, Japan\nTokyo, Japan\nCreated at the end of 2017 by Jerome Polin and Kevin Sendou, Nihongo Mantappu now has more than 5 million subscribers worldwide. Our content revolves around japanese culture, education, and personal life vlog of Jerome Polin. As of now, Nihongo Mantappu has over 6.000.000 subscriber nation-wide.\nCreated at the end of 2017 by Jerome Polin and Kevin Sendou, Nihongo Mantappu now has more than 5 million subscribers worldwide. Our content revolves around japanese culture, education, and personal life vlog of Jerome Polin. As of now, Nihongo Mantappu has over 6.000.000 subscriber nation-wide.',
#  'Founder\nFounder\nQ&A Group\nQ&A Group\nJun 2015 - Present · 6 yrs 10 mos\nJun 2015 - Present · 6 yrs 10 mos\nIndonesia\nIndonesia\nQ&A Group is a social media based learning official accounts. Q&A Group influenced over 500,000 of middle/high school students across Indonesia about the smart use of social media.\nQ&A Group is a social media based learning official accounts. Q&A Group influenced over 500,000 of middle/high school students across Indonesia about the smart use of social media.']

# %%
driver.close()

# %% [markdown]
# # Tugas
#
# 1. Ubah <b>Code 1</b> dan simpan hasil <i>crawling</i> (id dan teks) menggunakan <i>code</i> tersebut dengan nama `hasil_tweet_c1.csv`. Kode tersebut diubah berdasarkan ketentuan sebagai berikut:
#     * Jika Anda laki-laki dan angka-angka NPM Anda ditotalkan menjadi bilangan genap: *tweet* berbahasa Indonesia yang mengandung kata kunci `laki laki` dan tidak mengandung kata kunci `pria`
#     * Jika Anda laki-laki dan angka-angka NPM Anda ditotalkan menjadi bilangan ganjil: *tweet* berbahasa Indonesia yang mengandung kata kunci `lebaran` atau `idul fitri`
#     * Jika Anda perempuan dan angka-angka NPM Anda ditotalkan menjadi bilangan genap: original *tweet* (bukan retweet) berbahasa Indonesia yang mengandung kata kunci `rusia` dan `ukraina`, namun tidak boleh ada kemunculan `nato`.
#     * Jika Anda perempuan dan angka-angka NPM Anda ditotalkan menjadi bilangan ganjil: *tweet* berbahasa Indonesia dengan *hashtag* `#binomo` dan mengandung kata kunci `indra`, namun tidak boleh ada kemunculan `budi setiawan`.
#
#
# 2. Ubah <b>Code 2</b> dan simpan 5 <i>tweet</i> berbahasa Indonesia hasil <i>crawling</i> (id dan teks) menggunakan <i>code</i> tersebut dengan nama `hasil_tweet_c2.csv`. Kode tersebut diubah berdasarkan ketentuan sebagai berikut:
#     * Jika Anda angkatan 2019: *tweet* berbahasa Indonesia yang mengandung kata kunci `minyak goreng`
#     * Jika Anda bukan angkatan 2019: *tweet* berbahasa Indonesia yang mengandung kata kunci `saham`
#
#
# 3. Ubah <b>Code 3</b> dan simpan data profil dalam bentuk tabular dengan nama `hasil_twitter_profile_c3.csv`. Kode tersebut diubah berdasarkan ketentuan sebagai berikut:
#     * Jika Anda terakhir NPM Anda genap: akun dengan *username* @bibitid, @tulusm, dan @ibamibrahim
#     * Jika Anda bukan angkatan 2019: akun dengan *username* @marionjolamj, @gramedia, dan @mrlogix
#
#
# 4. Menggunakan data `goto.csv`, buat visualisasi:
#     * Jika nama Anda memiliki huruf vokal berjumlah genap: top 5 akun dengan *tweet* terbanyak (x-axis nama akun, y-axis jumlah *tweet*, urutkan dari *tweet* terbanyak)
#     * Jika nama Anda memiliki huruf vokal berjumlah ganjil: jumlah *tweet* per jam (x-axis jam tweet dibuat, y-axis jumlah *tweet*, urutkan berdasarkan jam terkecil, yaitu dari 00:00 sampai 23:00)
#
#
# 5. Ekstrak daftar:
#     * Jika nama Anda terdiri dari 1-2 kata: *following* dari akun @najwashihab menggunakan instaloader
#     * Jika nama Anda terdiri dari 3 atau lebih kata: *follower* dari akun @hampersbymiya menggunakan instaloader
#
#
# 6. Lakukan <i>scraping</i> profil Linkedin beberapa perusahaan bank terbesar di Indonesia sesuai dengan pembagian berikut:
# <table>
# <tr><th>Awalan huruf nama lengkap</th><th>URL Linkedin Perusahaan</th></tr>
# <tr><td>A-E</td><td>https://www.linkedin.com/company/pt.-bank-negara-indonesia-persero-tbk./</td></tr>
# <tr><td>F-Q</td><td>https://www.linkedin.com/company/bank-mandiri/</td></tr>
# <tr><td>R-Z</td><td>https://www.linkedin.com/company/bank-syariah-indonesia/</td></tr>
# </table>
# Informasi yang perlu diambil adalah nama, <i>bio</i>, dan jumlah *followers*. Berikut merupakan contoh hasil <i>scraping</i> dari profil Linkedin BSI:
#
# ```
# {
#     "nama": "PT Bank Syariah Indonesia Tbk.",
#     "bio": "Bersatu untuk Indonesia"
#     "followers": "30381"
# }
# ```
# <i>Note:</i> Anda bisa mendapatkan nilai bonus jika berhasil mendapatkan contoh 5 akun karyawan yang bekerja di perusahaan tersebut (dalam bentuk URL, misal: https://www.linkedin.com/in/jerome-polin-sijabat-b0241247/).
#
# <i>Deadline</i> pengumpulan Tugas adalah Sabtu, 26 Maret 2022 pukul 08:00 di SCeLE. Berkas yang dikumpulkan adalah Tutorial 1 - Data Collection.ipynb dan seluruh berkas csv. Kumpulkan semua berkas dalam zip dengan format penamaan Tutorial1_Nama_NPM.zip.

# %% [markdown]
# ### Jawaban

# %% [markdown]
# # 1
#
# Digit sum: 40
#
# *tweet* berbahasa Indonesia yang mengandung kata kunci `laki laki` dan tidak mengandung kata kunci `pria`

# %%
ppkm = tweepy_client.search_recent_tweets(query="(laki laki) -pria", max_results=10)

print("Jumlah tweet yang berhasil didapatkan: {}.\n".format(len(ppkm.data)))
# Out:
# Jumlah tweet yang berhasil didapatkan: 10.

# %%
# objek ppkm
ppkm
# Out:
# Response(data=[<Tweet id=1506207908744208388 text='RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.'>, <Tweet id=1506207902473744387 text='RT @Daks2022: Jackpot sa laki 😍😘 \n\nPangarap mo noon, subo subo kona ngayon 😋 Worth the wait naman talaga ❤️\n\nFollow me and Retweet to get D…'>, <Tweet id=1506207888481853454 text='ang laki nga ng cabinet ko, dami ko pa rin gamit nakakalat😡😡😡'>, <Tweet id=1506207883565826051 text='RT @agniasambara: Suka banget sama manga ini, diceritakan dari sudut pandang seorang ibu heteroseksual yang salah satu anak laki-lakinya ia…'>, <Tweet id=1506207879237234689 text='@bumbeetbum @aisyahchivchiew Oh ye ke. Aku minum sedap je. Rasa lega tekak. Laki aku minum kelapa lemon. Pun lega. Maybe lain org lain kot.'>, <Tweet id=1506207878692368384 text="RT @Mini0nnn02: BALIKO at ang LAKI ng TITI! He's into Her star paps Sean T. (New &amp; rare copy is now out!)\n\nLegit na JABULERO pala si Tiktok…">, <Tweet id=1506207877869932545 text='RT @agniasambara: Suka banget sama manga ini, diceritakan dari sudut pandang seorang ibu heteroseksual yang salah satu anak laki-lakinya ia…'>, <Tweet id=1506207876892700674 text='RT @AlterDaddy2022: Ang Laki subra 😊💦 https://t.co/rRi8I11Zxk'>, <Tweet id=1506207848920805379 text='RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.'>, <Tweet id=1506207826531983365 text='RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.'>], includes={}, errors=[], meta={'newest_id': '1506207908744208388', 'oldest_id': '1506207826531983365', 'result_count': 10, 'next_token': 'b26v89c19zqg8o3fpyqnro5p6k7of4a7i5oe9e1zvm3ct'})

# %%
# contoh data
ppkm.data
# Out:
# [<Tweet id=1506207908744208388 text='RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.'>,
#  <Tweet id=1506207902473744387 text='RT @Daks2022: Jackpot sa laki 😍😘 \n\nPangarap mo noon, subo subo kona ngayon 😋 Worth the wait naman talaga ❤️\n\nFollow me and Retweet to get D…'>,
#  <Tweet id=1506207888481853454 text='ang laki nga ng cabinet ko, dami ko pa rin gamit nakakalat😡😡😡'>,
#  <Tweet id=1506207883565826051 text='RT @agniasambara: Suka banget sama manga ini, diceritakan dari sudut pandang seorang ibu heteroseksual yang salah satu anak laki-lakinya ia…'>,
#  <Tweet id=1506207879237234689 text='@bumbeetbum @aisyahchivchiew Oh ye ke. Aku minum sedap je. Rasa lega tekak. Laki aku minum kelapa lemon. Pun lega. Maybe lain org lain kot.'>,
#  <Tweet id=1506207878692368384 text="RT @Mini0nnn02: BALIKO at ang LAKI ng TITI! He's into Her star paps Sean T. (New &amp; rare copy is now out!)\n\nLegit na JABULERO pala si Tiktok…">,
#  <Tweet id=1506207877869932545 text='RT @agniasambara: Suka banget sama manga ini, diceritakan dari sudut pandang seorang ibu heteroseksual yang salah satu anak laki-lakinya ia…'>,
#  <Tweet id=1506207876892700674 text='RT @AlterDaddy2022: Ang Laki subra 😊💦 https://t.co/rRi8I11Zxk'>,
#  <Tweet id=1506207848920805379 text='RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.'>,
#  <Tweet id=1506207826531983365 text='RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.'>]

# %%
# parse ke format tabular (pandas dataframe)
import pandas as pd
pd.set_option('max_colwidth', 1000)

df_ppkm = pd.DataFrame()
for t in ppkm.data:
    df_ppkm = df_ppkm.append({
        'id': t.id,
        'text': t.text
    }, ignore_index=True)

df_ppkm
# Out:
#              id  \
# 0  1.506208e+18
# 1  1.506208e+18
# 2  1.506208e+18
# 3  1.506208e+18
# 4  1.506208e+18
# 5  1.506208e+18
# 6  1.506208e+18
# 7  1.506208e+18
# 8  1.506208e+18
# 9  1.506208e+18
#
#                                                                                                                                                  text
# 0                                                                    RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.
# 1    RT @Daks2022: Jackpot sa laki 😍😘 \n\nPangarap mo noon, subo subo kona ngayon 😋 Worth the wait naman talaga ❤️\n\nFollow me and Retweet to get D…
# 2                                                                                       ang laki nga ng cabinet ko, dami ko pa rin gamit nakakalat😡😡😡
# 3        RT @agniasambara: Suka banget sama manga ini, diceritakan dari sudut pandang seorang ibu heteroseksual yang salah satu anak laki-lakinya ia…
# 4         @bumbeetbum @aisyahchivchiew Oh ye ke. Aku minum sedap je. Rasa lega tekak. Laki aku minum kelapa lemon. Pun lega. Maybe lain org lain kot.
# 5  RT @Mini0nnn02: BALIKO at ang LAKI ng TITI! He's into Her star paps Sean T. (New &amp; rare copy is now out!)\n\nLegit na JABULERO pala si Tiktok…
# 6        RT @agniasambara: Suka banget sama manga ini, diceritakan dari sudut pandang seorang ibu heteroseksual yang salah satu anak laki-lakinya ia…
# 7                                                                                       RT @AlterDaddy2022: Ang Laki subra 😊💦 https://t.co/rRi8I11Zxk
# 8                                                                    RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.
# 9                                                                    RT @gadisssmelayu: ilang nya harga diri laki-laki ketika dia minta duit ke cewe.

# %%
df_ppkm.to_csv("hasil_tweet_c1.csv")

# %% [markdown]
# # 2
#
# *tweet* berbahasa Indonesia yang mengandung kata kunci `minyak goreng`

# %%
# import library

arr = []
class CustomStreamingClient2(StreamingClient):
    def on_tweet(self, tweet):
        arr.append([tweet.id, tweet.text])
        print(tweet.id, tweet.text)

    def on_connection_error(self):
        print("Connection error, stopping stream...")
        self.disconnect()

# %%
custom_stream_mg = CustomStreamingClient2(bearer_token)

# membuat rules untuk filter
custom_stream_mg.add_rules(tweepy.StreamRule("(minyak goreng)"))
custom_stream_mg.add_rules(tweepy.StreamRule("lang:id"))

custom_stream_mg.filter()
# Out:
# 1506216088476200960 RT @dianasayangku: Selain minyak goreng, yang stoknya harus selalu ada di rumahku adalah Minyak Kutus-Kutus. Mau restock ah, ikutan yuk. Op…
# 1506216111515537409 😭😭😭 https://t.co/9YqL5I64oI
# 1506216121820925958 RT @Onl1Jb: Konglomerat Minyak Goreng https://t.co/3fNiAV4lXD
# 1506216135590834181 RT @QaillaAsyiqah: Aksi Aliansi Mahasiswa se-Provinsi Jambi di kantor Gubernur Jambi | Dengan tuntutan Turunkan Harga Bahan Pokok &amp; Minyak…
# 1506216157681909760 Presiden Joko Widodo Cabut Subsidi Minyak Goreng, Ini Kata KSP
# https://t.co/GQ1QKUVICL
# 1506216162295570437 RT @QaillaAsyiqah: Lawan Oligarki ~ Aksi Komite Rakyat, Komponen Mahasiswa, Pelajar &amp; Emak².. (Jakarta 22/Mart/2022)
#
# Turunkan Harga Pokok…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ichsan\Documents\proj\ams\tutorial3_Data Collection\Tutorial 3 - Data Collection.ipynb Cell 82' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/Tutorial%203%20-%20Data%20Collection.ipynb#ch0000081?line=3'>4</a> custom_stream_mg.add_rules(tweepy.StreamRule("(minyak goreng)"))
#       <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/Tutorial%203%20-%20Data%20Collection.ipynb#ch0000081?line=4'>5</a> custom_stream_mg.add_rules(tweepy.StreamRule("lang:id"))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ichsan/Documents/proj/ams/tutorial3_Data%20Collection/Tutorial%203%20-%20Data%20Collection.ipynb#ch0000081?line=6'>7</a> custom_stream_mg.filter()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py:745, in StreamingClient.filter(self, threaded, **params)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=742'>743</a>     return self._threaded_connect(method, endpoint, params=params)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=743'>744</a> else:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=744'>745</a>     self._connect(method, endpoint, params=params)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py:570, in StreamingClient._connect(self, method, endpoint, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=567'>568</a> self.session.headers["Authorization"] = f"Bearer {self.bearer_token}"
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=568'>569</a> url = f"https://api.twitter.com/2/tweets/{endpoint}/stream"
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=569'>570</a> super()._connect(method, url, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py:87, in BaseStream._connect(self, method, url, auth, params, headers, body)
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=83'>84</a> if not self.running:
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=84'>85</a>     break
# ---> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=86'>87</a> for line in resp.iter_lines(
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=87'>88</a>     chunk_size=self.chunk_size
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=88'>89</a> ):
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=89'>90</a>     if line:
#      <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/tweepy/streaming.py?line=90'>91</a>         self.on_data(line)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py:804, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=794'>795</a> """Iterates over the response data, one line at a time.  When
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=795'>796</a> stream=True is set on the request, this avoids reading the
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=796'>797</a> content at once into memory for large responses.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=797'>798</a>
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=798'>799</a> .. note:: This method is not reentrant safe.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=799'>800</a> """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=801'>802</a> pending = None
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=803'>804</a> for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=805'>806</a>     if pending is not None:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=806'>807</a>         chunk = pending + chunk
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\models.py:760, in Response.iter_content.<locals>.generate()
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=757'>758</a> if hasattr(self.raw, 'stream'):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=758'>759</a>     try:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=759'>760</a>         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=760'>761</a>             yield chunk
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/requests/models.py?line=761'>762</a>     except ProtocolError as e:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py:572, in HTTPResponse.stream(self, amt, decode_content)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=555'>556</a> """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=556'>557</a> A generator wrapper for the read() method. A call will block until
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=557'>558</a> ``amt`` bytes have been read from the connection or until the
#    (...)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=568'>569</a>     'content-encoding' header.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=569'>570</a> """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=570'>571</a> if self.chunked and self.supports_chunked_reads():
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=571'>572</a>     for line in self.read_chunked(amt, decode_content=decode_content):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=572'>573</a>         yield line
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=573'>574</a> else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py:764, in HTTPResponse.read_chunked(self, amt, decode_content)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=760'>761</a>     return
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=762'>763</a> while True:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=763'>764</a>     self._update_chunk_length()
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=764'>765</a>     if self.chunk_left == 0:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=765'>766</a>         break
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py:694, in HTTPResponse._update_chunk_length(self)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=691'>692</a> if self.chunk_left is not None:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=692'>693</a>     return
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=693'>694</a> line = self._fp.fp.readline()
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=694'>695</a> line = line.split(b";", 1)[0]
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/urllib3/response.py?line=695'>696</a> try:
#
# File C:\ProgramData\Anaconda3\lib\socket.py:669, in SocketIO.readinto(self, b)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=666'>667</a> while True:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=667'>668</a>     try:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=668'>669</a>         return self._sock.recv_into(b)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=669'>670</a>     except timeout:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/socket.py?line=670'>671</a>         self._timeout_occurred = True
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# cek rules yang sudah di-add
custom_stream_mg.get_rules()
# Out:
# Response(data=[StreamRule(value='(minyak goreng)', tag=None, id='1506216112949669888')], includes={}, errors=[], meta={'sent': '2022-03-22T12:28:38.999Z', 'result_count': 1})

# %%
# custom_stream_mg.delete_rules('1506211439694196737')

# %%
len(arr)
# Out:
# 11

# %%
minyak_df = pd.DataFrame(arr, columns=['id', 'teks'])

# %%
minyak_df.to_csv("hasil_tweet_c2.csv")

# %% [markdown]
# # 3
#
# *username* @bibitid, @tulusm, dan @ibamibrahim

# %%
# field user yg ingin diambil, referensi: https://developer.twitter.com/en/docs/twitter-api/data-dictionary/object-model/user
fields = "created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld"
params = {"usernames": "bibitid,tulusm,ibamibrahim", "user.fields": fields}
request_token_url = "https://api.twitter.com/oauth/request_token"
oauth = OAuth1Session(consumer_key, client_secret=consumer_secret)
fetch_response = oauth.fetch_request_token(request_token_url)

# %%
# objek response
fetch_response
# Out:
# {'oauth_token': 'rApjTgAAAAABaVF7AAABf7E2d0o',
#  'oauth_token_secret': 'hiLc0hPHY4qj5VofS0mMj8hIJRsmJrOk',
#  'oauth_callback_confirmed': 'true'}

# %%
resource_owner_key = fetch_response.get("oauth_token")
resource_owner_secret = fetch_response.get("oauth_token_secret")

# %%
# authorisasi
base_authorization_url = "https://api.twitter.com/oauth/authorize"
authorization_url = oauth.authorization_url(base_authorization_url)
print("Please go here and authorize: %s" % authorization_url)
verifier = input("Paste the PIN here: ")
# Out:
# Please go here and authorize: https://api.twitter.com/oauth/authorize?oauth_token=rApjTgAAAAABaVF7AAABf7E2d0o

# %%
# Get the access token
access_token_url = "https://api.twitter.com/oauth/access_token"
oauth = OAuth1Session(
    consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=resource_owner_key,
    resource_owner_secret=resource_owner_secret,
    verifier=verifier,
)
oauth_tokens = oauth.fetch_access_token(access_token_url)

access_token = oauth_tokens["oauth_token"]
access_token_secret = oauth_tokens["oauth_token_secret"]

# make the request
oauth = OAuth1Session(
    consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=access_token,
    resource_owner_secret=access_token_secret,
)

# %%
response = oauth.get(
    "https://api.twitter.com/2/users/by", params=params
)

if response.status_code != 200:
    raise Exception(
        "Request returned an error: {} {}".format(response.status_code, response.text)
    )

print("Response code: {}".format(response.status_code))
# Out:
# Response code: 200

# %%
# objek response
pd.DataFrame(json_response['data']).to_csv("hasil_twitter_profile_c3.csv")

# %% [markdown]
# # 4
#
# top 5 akun dengan *tweet* terbanyak (x-axis nama akun, y-axis jumlah *tweet*, urutkan dari *tweet* terbanyak)

# %%
df_goto.head()
# Out:
#                     id      conversation_id  \
# 0  1503883736345366530  1503883736345366530
# 1  1503883692493606915  1503680965595451395
# 2  1503883672705028099  1503883424192421893
# 3  1503883640983650307  1503883640983650307
# 4  1503883626114859009  1503883626114859009
#
#                                   created_at        date      time  timezone  \
# 0  2022-03-16 06:59:58 SE Asia Standard Time  2022-03-16  06:59:58       700
# 1  2022-03-16 06:59:47 SE Asia Standard Time  2022-03-16  06:59:47       700
# 2  2022-03-16 06:59:43 SE Asia Standard Time  2022-03-16  06:59:43       700
# 3  2022-03-16 06:59:35 SE Asia Standard Time  2022-03-16  06:59:35       700
# 4  2022-03-16 06:59:31 SE Asia Standard Time  2022-03-16  06:59:31       700
#
#                user_id         username                name place  ... geo  \
# 0  1376072002298019849          14106_s  ぷ。 ฅ(ᵔᴥᵔ)ฅやわやわ🚶‍♀️   NaN  ... NaN
# 1   992932185144348672  mowchan_mowchan            MOW/元保育者   NaN  ... NaN
# 2  1227999980654407680  stemthebleeding     STEMtheBleeding   NaN  ... NaN
# 3   918325280950726656    osanpo_hiyoko            tekupiyo   NaN  ... NaN
# 4  1495109550596190212          goto1ri                  ☁️   NaN  ... NaN
#
#   source user_rt_id user_rt retweet_id  \
# 0    NaN        NaN     NaN        NaN
# 1    NaN        NaN     NaN        NaN
# 2    NaN        NaN     NaN        NaN
# 3    NaN        NaN     NaN        NaN
# 4    NaN        NaN     NaN        NaN
#
#                                                                                  reply_to  \
# 0                                                                                      []
# 1  [{'screen_name': 'LugcNzz4CPY0roF', 'name': 'たまご 6y&2y', 'id': '1264785023137271808'}]
# 2       [{'screen_name': 'fit__feminist', 'name': 'Abadass Mom Bod', 'id': '4597876452'}]
# 3                                                                                      []
# 4                                                                                      []
#
#    retweet_date  translate trans_src trans_dest
# 0           NaN        NaN       NaN        NaN
# 1           NaN        NaN       NaN        NaN
# 2           NaN        NaN       NaN        NaN
# 3           NaN        NaN       NaN        NaN
# 4           NaN        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
res = df_goto.groupby("username").size().sort_values(ascending=False)[:5]
res
# Out:
# username
# hotelsmarker      280
# goto714poppin      77
# goto_buscenter     67
# go2goto5           60
# leengoto           49
# dtype: int64

# %%
res.plot(kind='bar').set_ylabel("Jumlah tweet")
# Out:
# Text(0, 0.5, 'Jumlah tweet')

# %% [markdown]
# # 5
#
# *follower* dari akun @hampersbymiya menggunakan instaloader

# %%
profile = Profile.from_username(loader.context, 'hampersbymiya')
# objek profile
profile
# Out:
# <Profile hampersbymiya (47726860011)>

# %%
df_profile = pd.DataFrame({
    'userid': [profile.userid],
    'username': [profile.username],
    'is_private': [profile.is_private],
    'mediacount': [profile.mediacount],
    'igtvcount': [profile.igtvcount],
    'followers': [profile.followers],
    'followees': [profile.followees],
    'external_url': [profile.external_url],
    'is_business_account': [profile.is_business_account],
    'business_category_name': [profile.business_category_name],
    'biography': [profile.biography],
    'full_name': [profile.full_name],
    'has_public_story': [profile.has_public_story],
    'is_verified': [profile.is_verified],
    'profile_pic_url': [profile.profile_pic_url]
}) 

df_profile
# Out:
#         userid       username  is_private  mediacount  igtvcount  followers  \
# 0  47726860011  hampersbymiya       False          78          4        635
#
#    followees                     external_url  is_business_account  \
# 0        121  https://linktr.ee/Hampersbymiya                 True
#
#                         business_category_name  \
# 0  Personal Goods & General Merchandise Stores
#
#                                                                                                                                       biography  \
# 0  Gift you will admire 💝\nCurated by @lilyanaputri @tennyradestriana @meaqr ✨\nOrder maks H-1 jam 13.00 \nClick for order or more info\n⬇️⬇️⬇️
#
#                     full_name  has_public_story  is_verified  \
# 0  Hampers & Gift Set Bandung             False        False
#
#                                                                                                                                                                                                                                                                                      profile_pic_url
# 0  https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/194582713_816478615660455_2603408664688059549_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=5cRBzCTLf3EAX_54KIl&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8JU1zD9feLwfzUgl-Q93wJOQSXkrivvwQyuSeRYXY2TA&oe=623FA90C&_nc_sid=a9513d

# %%
list_followers = []
for p in profile.get_followers():
    list_followers.append(
    {
    'userid': [p.userid],
    'username': [p.username],
    'is_private': [p.is_private],
    'mediacount': [p.mediacount],
    'igtvcount': [p.igtvcount],
    'followers': [p.followers],
    'followees': [p.followees],
    'external_url': [p.external_url],
    'is_business_account': [p.is_business_account],
    'business_category_name': [p.business_category_name],
    'biography': [p.biography],
    'full_name': [p.full_name],
    'has_public_story': [p.has_public_story],
    'is_verified': [p.is_verified],
    'profile_pic_url': [p.profile_pic_url]
    }
    )
# Out:
# Too many queries in the last time. Need to wait 75 seconds, until 06:57.
#
# Too many queries in the last time. Need to wait 79 seconds, until 07:08.
#
# Too many queries in the last time. Need to wait 92 seconds, until 07:16.
#
# Too many queries in the last time. Need to wait 21 seconds, until 07:20.
#
# Too many queries in the last time. Need to wait 68 seconds, until 07:27.
#
# Too many queries in the last time. Need to wait 20 seconds, until 07:33.
# JSON Query to el_caraka_senja/feed/: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)) [retrying; skip with ^C]
# Too many queries in the last time. Need to wait 54 seconds, until 07:39.
#
# Too many queries in the last time. Need to wait 67 seconds, until 07:47.
#
# Too many queries in the last time. Need to wait 22 seconds, until 07:54.
#
# Too many queries in the last time. Need to wait 21 seconds, until 07:55.
#
# Too many queries in the last time. Need to wait 18 seconds, until 07:56.
#
# Too many queries in the last time. Need to wait 67 seconds, until 07:58.
#
# Too many queries in the last time. Need to wait 24 seconds, until 08:05.
#
# Too many queries in the last time. Need to wait 18 seconds, until 08:06.
#
# Too many queries in the last time. Need to wait 56 seconds, until 08:09.
#
# Too many queries in the last time. Need to wait 89 seconds, until 08:17.

# %%
len(list_followers)
# Out:
# 634

# %%
list_followers
# Out:
# [{'userid': [941594177],
#   'username': ['dianutamianinda'],
#   'is_private': [True],
#   'mediacount': [270],
#   'igtvcount': [9],
#   'followers': [668],
#   'followees': [1790],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['DIANANINDA'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/38811240_2118354328387139_4883075024652599296_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=ZAIwpZFNrVUAX8oDr20&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_vITT9J5IvrvObAP0XwEQw8NWJWK1ufP-5exwRK2va9w&oe=6245AC26&_nc_sid=a9513d']},
#  {'userid': [1015900134],
#   'username': ['srianik'],
#   'is_private': [False],
#   'mediacount': [114],
#   'igtvcount': [0],
#   'followers': [959],
#   'followees': [707],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['menerima pesanan coklat karakter dan batik tulis maupun cap dan printing\nuntuk pemesanan silahkan hub : \nhp : 081325455570/081210243984\nBBM : 54456C80'],
#   'full_name': ['sri anik'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/11925668_403126463212878_1115656717_a.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=dxpCPItpl6QAX-Xy0Ax&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8MzoSoOYf6-TsgHwbunGOTSxMgDDBUrngj8k4888iubA&oe=62446CB3&_nc_sid=a9513d']},
#  {'userid': [46982256592],
#   'username': ['mumu6915'],
#   'is_private': [False],
#   'mediacount': [68],
#   'igtvcount': [4],
#   'followers': [284],
#   'followees': [748],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['DPD PWRI JAYA JABAR'],
#   'full_name': ['Mumu'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/275699490_716595599353647_8049508833111327248_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=j1ojUdwrb7AAX9nqA-v&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_Lh3EWZC9QY4An0xV49CZ_unwOTCyO78bGzAIdz1uHag&oe=62460071&_nc_sid=a9513d']},
#  {'userid': [2100069512],
#   'username': ['upiek.henry'],
#   'is_private': [True],
#   'mediacount': [29],
#   'igtvcount': [2],
#   'followers': [28],
#   'followees': [92],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Upiek Henry'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/11226795_784345531673460_580446543_a.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=XI4eaNbQ2XAAX-NjE19&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8rnSNIHG61X42_n1O5Y-k6a99UO_vyZgyVZC69nk69tQ&oe=62447943&_nc_sid=a9513d']},
#  {'userid': [3943292403],
#   'username': ['heni_sarwono'],
#   'is_private': [False],
#   'mediacount': [1149],
#   'igtvcount': [20],
#   'followers': [1466],
#   'followees': [4313],
#   'external_url': [None],
#   'is_business_account': [True],
#   'business_category_name': ['Creators & Celebrities'],
#   'biography': [''],
#   'full_name': ['Heni Sarwono'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/58639179_497649977645685_7321540310364848128_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=mDPRI39HZXgAX8BYPvq&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-oWkidhPZQG_xyuBtOIiPYuiaoPLq6AI3PHKXIPb1o9g&oe=6245C0DF&_nc_sid=a9513d']},
#  {'userid': [8415121255],
#   'username': ['violarahmah34'],
#   'is_private': [False],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [235],
#   'followees': [1270],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['violarahmah'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/49500182_1967089810252612_3146062096916021248_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=ag6wham9dkUAX9xz0xJ&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_3kAA-IjTPE7bAT8YhApkid_qW0ydqpgapuexFXObOHA&oe=6245EB5B&_nc_sid=a9513d']},
#  {'userid': [52012859038],
#   'username': ['tenunsongket2020'],
#   'is_private': [False],
#   'mediacount': [34],
#   'igtvcount': [1],
#   'followers': [46],
#   'followees': [574],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Kain tenun songket Sumba Timur-NTT\nproduk lokal\n#kaintenunsongket #cintaprodukindonesia #kaintenunntt  #gointernasionalfasion  #tenunsongketmurah'],
#   'full_name': ['Kain songket Sumba Timur-NTT'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/275059113_501836674866706_6862321914034762758_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=cjfadT_spa4AX-YZiIq&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_F0lywo54EbL5r_gyzfat7-6Z3MIobqwNpEDr4ZuUAHg&oe=6245A35A&_nc_sid=a9513d']},
#  {'userid': [1757619550],
#   'username': ['ristinindriyanti'],
#   'is_private': [True],
#   'mediacount': [13],
#   'igtvcount': [1],
#   'followers': [1116],
#   'followees': [649],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['-بِسْمِ اللهِ الرَّحْمنِ الرَّحِيمِ-\n@rizkyris02 💜\n@nbs.kroya'],
#   'full_name': ['Ristin'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/275051898_1011088723120343_7715102065898405884_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=R4ZkX9gFhxMAX_G2v18&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9BRT0Ynp-6-iH8cdidKAPXswEO-9T0e4OotNEShwqoWQ&oe=62444DBD&_nc_sid=a9513d']},
#  {'userid': [51610143575],
#   'username': ['alfarisi.online'],
#   'is_private': [False],
#   'mediacount': [22],
#   'igtvcount': [0],
#   'followers': [871],
#   'followees': [197],
#   'external_url': [None],
#   'is_business_account': [True],
#   'business_category_name': ['Personal Goods & General Merchandise Stores'],
#   'biography': ['Offset, digital, sablon, logam \n💻 Desain gratis\n🛍️ Uji bahan kemasan (Dummy)\n☎️ konsultasi desain dan produk\n🚚 Kirim se Indonesia Raya 🇮🇩'],
#   'full_name': ['Irwan'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/270216671_222356266684636_2214576524574656437_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=9HAdKInLhpYAX-ujkMf&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8byLerhzX5frqPH10_mv_Tue8uVIkW1pIQB2h6bnP_eg&oe=62456845&_nc_sid=a9513d']},
#  {'userid': [1688470883],
#   'username': ['sabe_kupi'],
#   'is_private': [False],
#   'mediacount': [10],
#   'igtvcount': [5],
#   'followers': [469],
#   'followees': [496],
#   'external_url': [None],
#   'is_business_account': [True],
#   'business_category_name': ['Restaurants'],
#   'biography': ['@smrprime'],
#   'full_name': ['sabe_kupi'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/262876590_1427997767660750_1232879963899949496_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=JAokeuR7jU0AX8z2J5i&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-rLo1IniBepra7EqmDpaYXrKsnCPibpu2V34SBTTp2og&oe=62455302&_nc_sid=a9513d']},
#  {'userid': [352135430],
#   'username': ['kristianabeby_syarif'],
#   'is_private': [True],
#   'mediacount': [683],
#   'igtvcount': [5],
#   'followers': [1238],
#   'followees': [3694],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Kristiana'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/272041439_1022482168478542_6471795096634543436_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=22PnCkhUp9sAX9cGGrV&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT89sRfoaJBHo7SKe6N5V9q7aSDP2sZq2F7aElC98KXwVA&oe=62459E3F&_nc_sid=a9513d']},
#  {'userid': [42140408153],
#   'username': ['hr_hardiansyah'],
#   'is_private': [True],
#   'mediacount': [60],
#   'igtvcount': [12],
#   'followers': [244],
#   'followees': [4004],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Logistic & Business\nFor Information DM 📲'],
#   'full_name': ['Hardi'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/136117221_219527739803323_6416063719601529655_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=NCD2vxoqmHAAX_nBUnm&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_8CnsLvly893nrWnSwCWNocXEc0xoRfgLSeA4TxEL7MQ&oe=6245952F&_nc_sid=a9513d']},
#  {'userid': [50694694649],
#   'username': ['handty11'],
#   'is_private': [False],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [6],
#   'followees': [53],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['handty'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fcgk22-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?efg=eyJybWQiOiJpZ19hbmRyb2lkX21vYmlsZV9uZXR3b3JrX3N0YWNrX3Bvc3Rfd2l0aF9uZXdfdGNwX2ZhbGxiYWNrXzQ6cG9zdCJ9&_nc_ht=instagram.fcgk22-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=kLQ4jXKOCJIAX94ZgPr&edm=ANct6CgBAAAA&ccb=7-4&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4&oh=00_AT9cx6Qug8vqUVcCbuQj-qgy5RyIKgF2LDAB-RwMGZ19ew&oe=624465CF&_nc_sid=e4e9cf']},
#  {'userid': [4095073649],
#   'username': ['ratu.mulya'],
#   'is_private': [True],
#   'mediacount': [1071],
#   'igtvcount': [182],
#   'followers': [185],
#   'followees': [2884],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Mother of two kids 👩\u200d👦\u200d👦'],
#   'full_name': ['ratu mulya'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/152546903_808189646429320_3367373926699457772_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=Nb30a-Z17IIAX9q_Shj&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-AwHtugjus8eLMHpD4pjYaqv2BchL8E8dmuLX5P4gHmg&oe=6245BB18&_nc_sid=a9513d']},
#  {'userid': [49057593971],
#   'username': ['_erikaayyu'],
#   'is_private': [False],
#   'mediacount': [5],
#   'igtvcount': [0],
#   'followers': [248],
#   'followees': [402],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['🏁@controlspeedbdg'],
#   'full_name': ['Erika rahayu'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/273902332_1120335402054930_3016013165785499191_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=HW3rj2wUewAAX91X028&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-08JWqDOwMgFiEUhioW0h4170xkRk5Y8mGA1BJbX9M2A&oe=6245E058&_nc_sid=a9513d']},
#  {'userid': [39676029602],
#   'username': ['witrie17'],
#   'is_private': [False],
#   'mediacount': [9],
#   'igtvcount': [6],
#   'followers': [173],
#   'followees': [213],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['witri nirmalasari'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/116238860_178489063657030_9164445485572873002_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=28USM8bfrcwAX-5L6l3&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8ypR_2E4HtatZEB1BPQBnP2BqlZSpaCuzQ_k3ZhFK4Xw&oe=6245CB89&_nc_sid=a9513d']},
#  {'userid': [50084335173],
#   'username': ['aisyahrahcma'],
#   'is_private': [False],
#   'mediacount': [98],
#   'igtvcount': [92],
#   'followers': [605],
#   'followees': [4729],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Mfarikarfan❤'],
#   'full_name': ['panggil ai aja'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/273669782_623639408737505_5211701211625991470_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=PBeqMsyMVdkAX8sih5h&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_EeOjuqFngh47Khv8ckdPIhnFtU-R9kIdlcfJG_vHjTQ&oe=6245D644&_nc_sid=a9513d']},
#  {'userid': [4197214790],
#   'username': ['salimidham'],
#   'is_private': [True],
#   'mediacount': [42],
#   'igtvcount': [2],
#   'followers': [156],
#   'followees': [120],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Idham Aulia Salim'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/14582289_1345739868783726_2712455766513549312_a.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=eAbmQeM-xWUAX8IN16F&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT97MSsx0EE9EZxuR6LopS0W2awQww65nofh8wjBpboI0A&oe=62462105&_nc_sid=a9513d']},
#  {'userid': [415771154],
#   'username': ['sandi210484'],
#   'is_private': [True],
#   'mediacount': [564],
#   'igtvcount': [64],
#   'followers': [896],
#   'followees': [3159],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Umminya Regan,Aika,Alana'],
#   'full_name': ['Umminya Regan Aika Alana'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/269886683_608914970407101_6509563231316080777_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=D-6E1JKXVIwAX-WcDqL&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-pZnJ5W0GMJfW3CXuMSGk6Kg-wu0cSLGDv_fUHLPPwMw&oe=6245C3AD&_nc_sid=a9513d']},
#  {'userid': [367570224],
#   'username': ['dessyrazak'],
#   'is_private': [False],
#   'mediacount': [245],
#   'igtvcount': [5],
#   'followers': [982],
#   'followees': [4526],
#   'external_url': [None],
#   'is_business_account': [True],
#   'business_category_name': ['Personal Goods & General Merchandise Stores'],
#   'biography': ['Terima pesanan kue'],
#   'full_name': ['Dessynya Aderazak'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/164915353_541713730132517_8572427847273688749_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=L-_HdmRgck8AX_BulXl&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_1MxYcTJ2GrUNP6uZZn1FnCQbFjuK9qQkTs0xu96Ttgg&oe=62455AF6&_nc_sid=a9513d']},
#  {'userid': [2135634358],
#   'username': ['herawati_aneng'],
#   'is_private': [True],
#   'mediacount': [146],
#   'igtvcount': [9],
#   'followers': [427],
#   'followees': [642],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Herawati_Aneng'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/167486492_799065330718054_4745501215650639716_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=rl8aBMmqQWoAX-eE49u&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9fXEkdA7sw9CdavfxKInmmMxBI1AxlRt0hycvPUQJOZA&oe=6245A497&_nc_sid=a9513d']},
#  {'userid': [1303464683],
#   'username': ['inneuanneu'],
#   'is_private': [False],
#   'mediacount': [318],
#   'igtvcount': [28],
#   'followers': [1597],
#   'followees': [2068],
#   'external_url': ['https://www.youtube.com/channel/UC5FafmxHAWgC71e896lDppw'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['@aden_arkhan  @arkhan_aden'],
#   'full_name': ['Irene Rusmayanti'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/137063406_204848057969644_7884887192665414590_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=Rlf-A35weOMAX-se_42&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8tH1VulhvoH5BBpsq5bZAeBhwBW00n_3poIPiPrFrM-A&oe=6245E5E8&_nc_sid=a9513d']},
#  {'userid': [2927783600],
#   'username': ['echa_seftiani'],
#   'is_private': [False],
#   'mediacount': [18],
#   'igtvcount': [1],
#   'followers': [788],
#   'followees': [1005],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Twiter\n@echa_seftyani 🌼🌞'],
#   'full_name': ['Echa Seftiani'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/260064960_330634392208491_394616007264532160_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=TsBaMlI4yLAAX82L1G2&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-n8Z8nD1KvrSj5CtHMe_pj9iWMdxBLan0SHDcoIyanpw&oe=62451051&_nc_sid=a9513d']},
#  {'userid': [2310285338],
#   'username': ['dewi047'],
#   'is_private': [True],
#   'mediacount': [298],
#   'igtvcount': [54],
#   'followers': [1257],
#   'followees': [1260],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Dewi Mulya Mulyani'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/161808023_547090346266826_6522388302870087667_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=zrRapkBMR_UAX9sUSsl&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8SFOeZY_sKU-FnfbTOlB-fJdggRjE_gut8vYer1NjoOA&oe=6244E59B&_nc_sid=a9513d']},
#  {'userid': [715959001],
#   'username': ['viviaann.11'],
#   'is_private': [True],
#   'mediacount': [95],
#   'igtvcount': [6],
#   'followers': [2326],
#   'followees': [1559],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['🤵@giman_rakashiwi 💕\n👶 Halona Giviyara Nakagawa ❤'],
#   'full_name': ['Bunda Halona❤️'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/268897200_1202054890204375_7396569703191823687_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=E_9lrz9ZZSIAX-l8Kc4&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-oRTcgEoC96Cc_VBMh1FXUZMmvkR-aEzCGEVAiq_GjVw&oe=6245B6F9&_nc_sid=a9513d']},
#  {'userid': [4590795896],
#   'username': ['p.melina_28'],
#   'is_private': [False],
#   'mediacount': [225],
#   'igtvcount': [18],
#   'followers': [789],
#   'followees': [2275],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Puji Melina'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/241707923_1664046650471500_3285392937402581443_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=TUy3CkMJQxEAX_D4SYM&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8GMzznWM3a8UpmQeNLxqHHJjcdM5dmk6Hln01XwJ3h3Q&oe=62456B0E&_nc_sid=a9513d']},
#  {'userid': [3409179401],
#   'username': ['fitriagiskakhaira'],
#   'is_private': [True],
#   'mediacount': [1388],
#   'igtvcount': [98],
#   'followers': [387],
#   'followees': [1391],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['👧🏼 Moms Gicka Aura Putri Arifin\n  👧🏼Moms Nesya Khaira Putri Arifin \n 👦🏼Moms Ghaisan Maqil Putra Arifin'],
#   'full_name': ['Fitria Giska Khaira Arifin'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/273142730_446148537239780_40953121198595561_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=0JxdZkcijd4AX8aKjZH&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_9Pdakeu83ek6ysmrc-vNd_ih9wb2d3L0xEx8Pr7FNJA&oe=62454740&_nc_sid=a9513d']},
#  {'userid': [2209100385],
#   'username': ['hestijessika'],
#   'is_private': [False],
#   'mediacount': [157],
#   'igtvcount': [14],
#   'followers': [3005],
#   'followees': [7502],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Hesti Jessika'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/39345037_880636342134631_4045091149600260096_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=-7ECwLc5qZQAX8KDS85&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8GlPZZ3jj_MEkSsSHXyfswy_bmfKxucTWSLyoeKdPZ-g&oe=6245E902&_nc_sid=a9513d']},
#  {'userid': [46973193433],
#   'username': ['my.allsho.id'],
#   'is_private': [False],
#   'mediacount': [18],
#   'igtvcount': [0],
#   'followers': [43],
#   'followees': [175],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['GIFT BOX\n✨ Hampers ✨\n📍 Kendal, Jawa Tengah\n📩 Pesan chatt Dm\n🏧 BCA, Mandiri\n🏡 Cepiring, Kendal Jawa Tengah\nFor Graduation, Birthday, Anniversary, etc'],
#   'full_name': ['my...'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/168036925_133702812037448_6482004505178218474_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=PhMNu-xbmi0AX9xyIPK&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-HHzOckaA3QKpTLvwjo6aufsaVE0oU0UNiLcwRPX6wyA&oe=62455273&_nc_sid=a9513d']},
#  {'userid': [33267711],
#   'username': ['nawiewazhere'],
#   'is_private': [True],
#   'mediacount': [141],
#   'igtvcount': [9],
#   'followers': [234],
#   'followees': [177],
#   'external_url': ['https://s.bankneo.co.id/Bn5a00'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Nawie Ridwan Achmad'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/11373918_1694236154139859_1261277644_a.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=LN6A9nMbJUQAX-KMrk_&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9THaIqZoHE4GLqEw-5FW22RKjE3WNEDcTJ1qewxAjl0Q&oe=62459817&_nc_sid=a9513d']},
#  {'userid': [6242042433],
#   'username': ['adriana.riska'],
#   'is_private': [True],
#   'mediacount': [226],
#   'igtvcount': [30],
#   'followers': [334],
#   'followees': [365],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['a proud mother of Raditya.. ENT Specialist ❤️❤️'],
#   'full_name': ['Riska Adriana'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/185310060_1411239619237544_1441271862793439542_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=lYcPpkjpKBEAX__GsbQ&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT85P0ECFs_wyX999qk88lcTxca8ne9_D7uFQrFJAk7Qbw&oe=62450AF2&_nc_sid=a9513d']},
#  {'userid': [1078156753],
#   'username': ['fitriibran'],
#   'is_private': [False],
#   'mediacount': [52],
#   'igtvcount': [2],
#   'followers': [485],
#   'followees': [490],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ["Hulwah Hu'uriyah"],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/22858250_367231750372707_6810676756781989888_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=z799-VOIzkYAX-R2_zc&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8lRDscd1Rwr-XT-_HN7AVGmgSsZFGIa1QuNDP-yWFynQ&oe=62460FD2&_nc_sid=a9513d']},
#  {'userid': [1462651715],
#   'username': ['kyuutuu'],
#   'is_private': [True],
#   'mediacount': [68],
#   'igtvcount': [2],
#   'followers': [997],
#   'followees': [1052],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['What are you looking for? 👀\nCOMING SOON @zhavproject'],
#   'full_name': ['Nabila Az-Zahraa'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/269954323_634277311043311_8938387404873271479_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=ZL4ZpT1Am_MAX-6kNWW&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9KEEXlJ0bk8x3iRSERuZeVImYi2nlvPItIa_MnX5vmIQ&oe=62463ABB&_nc_sid=a9513d']},
#  {'userid': [3400288243],
#   'username': ['wida_sheikha'],
#   'is_private': [True],
#   'mediacount': [81],
#   'igtvcount': [2],
#   'followers': [342],
#   'followees': [645],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['wida maulida'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/272725785_465870305211564_4417295028477860045_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=m1TeJx2rcsAAX_DFypz&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_PhZrDJWHkd9w0UZgzFj7K3eH-95rWGkuijrnNwdHKtg&oe=62448806&_nc_sid=a9513d']},
#  {'userid': [1546382501],
#   'username': ['nurul.79fatimah'],
#   'is_private': [True],
#   'mediacount': [309],
#   'igtvcount': [12],
#   'followers': [1113],
#   'followees': [1775],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Istiqomah..🙏#Meraih cinta Allah..😇'],
#   'full_name': ['Nurul Harkaasha Friadi'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/83674096_134476931242650_7056589361332092928_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=L8YXRYdBV0cAX_5IKm4&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_bEVeNschIJLbleEtxiGhuPtqWUCFJ14TlCMPtoiZ8aQ&oe=6244FDEF&_nc_sid=a9513d']},
#  {'userid': [1535215060],
#   'username': ['viena_ocktaviana'],
#   'is_private': [True],
#   'mediacount': [99],
#   'igtvcount': [7],
#   'followers': [1040],
#   'followees': [2985],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Viena Riady'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/153766926_531979094863386_2642058166705386726_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=4K_vQC9S2IcAX_lE3FM&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8bCKTXhISsWAy31ZhUdqAaQT6yyXei39_T4o0ov7Ev6g&oe=62453F6C&_nc_sid=a9513d']},
#  {'userid': [1324954163],
#   'username': ['sanifadhilah'],
#   'is_private': [False],
#   'mediacount': [40],
#   'igtvcount': [0],
#   'followers': [62],
#   'followees': [149],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Sani Fadhilah'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/10953612_601108283368584_752567774_a.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=PDdBaDn8oEEAX8qfyfW&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9-4yPWXKEQahctQflDXfgbFKHAKQa494iBD6qh1gnTQA&oe=62445B9E&_nc_sid=a9513d']},
#  {'userid': [238485287],
#   'username': ['ardyane87'],
#   'is_private': [True],
#   'mediacount': [207],
#   'igtvcount': [14],
#   'followers': [758],
#   'followees': [846],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ["Rafly, Raihan and Raksa''s mom"],
#   'full_name': ['Anye Ardyane Putri'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/11820602_907394702666875_1961169516_a.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=jh8TWM4Cp-0AX_i6DIT&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8HSfAcjRjeeNU5DwSH-S3LY1m05smuSuWhULEOIJmr7Q&oe=6244CBFF&_nc_sid=a9513d']},
#  {'userid': [7384243925],
#   'username': ['jillnm_03'],
#   'is_private': [True],
#   'mediacount': [2],
#   'igtvcount': [0],
#   'followers': [323],
#   'followees': [2067],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Assalamualaikum💛\nsunflowers🌻\njillnadhira20@gmail.com'],
#   'full_name': ['Jill Nadhira Maghani'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/248757877_253926440025320_9079384793064871430_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=NpqV1yxxIawAX-az634&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_q6gpToGA2R1eohm7iG740FIuM7JMo13Z2njeN4dZAeg&oe=62446A00&_nc_sid=a9513d']},
#  {'userid': [1482830661],
#   'username': ['mpiewafrie'],
#   'is_private': [False],
#   'mediacount': [220],
#   'igtvcount': [6],
#   'followers': [1681],
#   'followees': [3771],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['🧔🏻@jeniafrie \n👧@afriani_el'],
#   'full_name': ['Bunda Afriew'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/74602372_1184619265260813_2956037518081916928_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=Y-w3kj-ITawAX82p4QE&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8D_QP5kl86EC30gHuREA9uWCrY3Edo5jGc6udOrQVj7Q&oe=624542E0&_nc_sid=a9513d']},
#  {'userid': [535703033],
#   'username': ['armytriasari'],
#   'is_private': [True],
#   'mediacount': [130],
#   'igtvcount': [8],
#   'followers': [594],
#   'followees': [2075],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Army Triasari'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/12132861_1558415357766812_558868213_a.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=2ZRD67aq3SgAX_0q6F1&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9M7hnk2uYGnfoW4RT16Tsv6b5K3aj2BrReaVz5MR_I9g&oe=62452DFF&_nc_sid=a9513d']},
#  {'userid': [3611641693],
#   'username': ['miamarliana585'],
#   'is_private': [False],
#   'mediacount': [496],
#   'igtvcount': [28],
#   'followers': [791],
#   'followees': [2134],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['💍Epi hermawan\n👶Kazio Alfath Ibrahim'],
#   'full_name': ['Mia Marliana'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/241480949_831410480888474_2957754426670579391_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=cB2iU6w03oEAX8S5kR5&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT95WjwTNJ5SuJkWld1_aChOg0M6Cu9eGiK5cDU9eb5-pw&oe=6244BF4F&_nc_sid=a9513d']},
#  {'userid': [43859482956],
#   'username': ['hollaback957'],
#   'is_private': [False],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [6],
#   'followees': [92],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Beni Sahetapy'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fidr4-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fidr4-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=kLQ4jXKOCJIAX_Cgzaj&edm=AEsR1pMBAAAA&ccb=7-4&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4&oh=00_AT_ouotp9w9l1ztHhuxBrZ6FhbG84t_lYzlVkRfzVVFILg&oe=624465CF&_nc_sid=3f45ac']},
#  {'userid': [48317754829],
#   'username': ['ririm.bussines'],
#   'is_private': [False],
#   'mediacount': [20],
#   'igtvcount': [5],
#   'followers': [162],
#   'followees': [695],
#   'external_url': ['https://api.whatsapp.com/send?phone=6281254071005&text=Halo+Admin+Saya+Mau+Join'],
#   'is_business_account': [True],
#   'business_category_name': ['Creators & Celebrities'],
#   'biography': ['Full bimbingan 💯\n💸 Income 3juta-10juta /bulan\n🏧 Tidak harus ada ATM\n🔥 No MLM, 💯% HALAL \n➡️ Masuk GRUP\nFix join ? Chat 👇'],
#   'full_name': ['LOKER ONLINE PARA PELAJAR'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/229023952_524940771923363_4390570461711126618_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=lk4vfVp6ZGEAX-o6uDR&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT83zIq4hrhpgi4vOl1sbA8oJCkjXRmdHMjbSsWXDci1Pw&oe=62450976&_nc_sid=a9513d']},
#  {'userid': [48853292048],
#   'username': ['joeliandwi_h'],
#   'is_private': [True],
#   'mediacount': [2],
#   'igtvcount': [0],
#   'followers': [136],
#   'followees': [294],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['📍 Bandung'],
#   'full_name': ['Julian'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/271523279_158456623186274_1404189193714187772_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=RlYQGtTZJlQAX_0h3-R&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-cfnhK5tpvQ7dzcqxmbM8Lk5dk3_coLoetHmDclAHwTg&oe=62462D1F&_nc_sid=a9513d']},
#  {'userid': [47865135763],
#   'username': ['alsya.meilani'],
#   'is_private': [True],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [397],
#   'followees': [200],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['not like you.'],
#   'full_name': ['caaa'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/243626396_120365627033962_5892709123763282763_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=pv5B3-XBULkAX9nJP0o&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9a5wr76Q-eWMYxhGF-y1GOu9PVHxMPEUx4SwgJkvr1ug&oe=62448FB5&_nc_sid=a9513d']},
#  {'userid': [3303021217],
#   'username': ['didiusniya'],
#   'is_private': [False],
#   'mediacount': [2],
#   'igtvcount': [2],
#   'followers': [22487],
#   'followees': [3387],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ["*╔═══❖•ೋ° °ೋ•❖═══╗*\n❷4's | ❥𝚂𝙸𝙽𝙶𝙴𝚁 • 𝚂𝙾𝙽𝙶𝚆𝚁𝙸𝚃𝙴𝚁 ✍︎\n📍𝓢𝓪𝓫𝓪𝓱  🇲🇾\nDream + work = success\n*╚═══❖•ೋ° °ೋ•❖═══╝*"],
#   'full_name': ['𝓜𝓪𝔃𝓵𝔂𝓷 𝓨𝓪𝓷𝓲𝓴 ʕ•̫͡•ʔ'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/273272435_728901474677210_3027627458422497511_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=2biillOtKPIAX_9adSV&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_2YnLN1nufXgKcZwz5dZim83NPWqXI9HkvBw1kiCHveQ&oe=62453913&_nc_sid=a9513d']},
#  {'userid': [3238690695],
#   'username': ['xhaxhyajingga'],
#   'is_private': [False],
#   'mediacount': [3],
#   'igtvcount': [0],
#   'followers': [1070],
#   'followees': [4125],
#   'external_url': ['https://www.instagram.com/bankneocommerce'],
#   'is_business_account': [True],
#   'business_category_name': ['Creators & Celebrities'],
#   'biography': ['Marketing of BNC | Referral Code: ZF2R72 | @bankneocommerce'],
#   'full_name': ['Jingga | Marketing of BNC'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/220708243_253102236292414_5255508800708064035_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=Gvly-yvELiQAX9yYHeI&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9OHCohbpyaGyhIB4xB-dcY70ujWP6xjcNSPsxmQhVOUQ&oe=62450A77&_nc_sid=a9513d']},
#  {'userid': [894437167],
#   'username': ['sisthaaass'],
#   'is_private': [True],
#   'mediacount': [56],
#   'igtvcount': [3],
#   'followers': [737],
#   'followees': [749],
#   'external_url': ['https://soundcloud.com/sistha-swastika-796389274'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['@busis.food'],
#   'full_name': ['Sistha Swastika'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/235825584_993142108191274_8222354693065421784_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=rUOi_h1aPEMAX-fkxL4&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-EqJj5Be8BWZsgMCBYJgFy7x-1QMj9-Odas9osdTUHWA&oe=6244B77B&_nc_sid=a9513d']},
#  {'userid': [597161005],
#   'username': ['mamiya.authentic'],
#   'is_private': [False],
#   'mediacount': [1430],
#   'igtvcount': [1],
#   'followers': [4506],
#   'followees': [910],
#   'external_url': ['https://chat.whatsapp.com/GQISBRXgRpQFjVF52GWx51'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Brand new and preloved \nWA 081285318673 \nAll are authentic no KW2 no look alike. Trusted since Oct 2012.\n@jasatitip.dibandung \n@essentialoil.bandung'],
#   'full_name': ['We Only Sell Something Good'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/66472251_2382329058550048_1511079755133222912_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=-4fAqVnKQhkAX_pipUS&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT99dhrzsWki3ebQ0PII0_XB0K3Z_ZAqFiKbwtw-dATDSw&oe=6244871B&_nc_sid=a9513d']},
#  {'userid': [48358021137],
#   'username': ['imas_cirebon'],
#   'is_private': [True],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [269],
#   'followees': [3370],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Imas'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/271832370_484684893006627_1486049061821077281_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=sfYbm-eiJ_gAX_fZa5K&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9_FbBd33sX3EqYpapLGo3oDhtZ9J2783zWJqLWP1uKiQ&oe=6245CB96&_nc_sid=a9513d']},
#  {'userid': [445802077],
#   'username': ['lintanglintang_lsa'],
#   'is_private': [True],
#   'mediacount': [335],
#   'igtvcount': [29],
#   'followers': [1887],
#   'followees': [995],
#   'external_url': ['https://tokopedia.link/jEGh3iBVZ5'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Lintang LinTang'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/180284049_514256233078748_5898385179784439166_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=m9SHroDx6KwAX_Wk7eC&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8abCXp4kqcLU08pSuerTgb0Y1-qchrFGbJ94PKNlJGpg&oe=6245EB6E&_nc_sid=a9513d']},
#  {'userid': [1131835120],
#   'username': ['annisa027'],
#   'is_private': [False],
#   'mediacount': [327],
#   'igtvcount': [17],
#   'followers': [3375],
#   'followees': [7502],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Annisa Prameswari Nugraha'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/23596024_1990597357896220_8463782980085612544_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=AYbCnftinkMAX8W_UWA&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9xJ5vPa46YGzLcx42lgCeitz5kLNz-fdFTknWa2cq9Sg&oe=624633F6&_nc_sid=a9513d']},
#  {'userid': [210712542],
#   'username': ['mommyvania'],
#   'is_private': [True],
#   'mediacount': [1852],
#   'igtvcount': [255],
#   'followers': [996],
#   'followees': [1547],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Play the moments. Pause the memories. Stop the pain. Rewind the happiness'],
#   'full_name': ['Debby Felicia Ully'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/12224335_866915406749447_735168550_a.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=nYl3-jhZ1fwAX_wIh3c&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9beK__KloYPk5iX7wUgElRfjRbZeEBOZ1mNJo6mMuJEw&oe=6245216F&_nc_sid=a9513d']},
#  {'userid': [1936566733],
#   'username': ['iman0427'],
#   'is_private': [True],
#   'mediacount': [651],
#   'igtvcount': [63],
#   'followers': [230],
#   'followees': [999],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['*my little photodiary*\n#thestoryofmisstargram\nfaith-hope-love'],
#   'full_name': ['m.adelina.n'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/276284185_148098904357816_1047423361321844155_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=-6uhMnbGP6UAX_pwhA0&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9Qom6GqYzq6sn1zpmdCA-FBcPLWiElVp5h1xOqFT-4Mg&oe=6245B817&_nc_sid=a9513d']},
#  {'userid': [402595656],
#   'username': ['noviariani32'],
#   'is_private': [True],
#   'mediacount': [403],
#   'igtvcount': [28],
#   'followers': [664],
#   'followees': [1649],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Novi Ariani'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/90064505_208671650374174_5067843023077900288_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=uUXDo-0PFJYAX_SCmzq&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-3u5tTACDBQDtQ_-JcpzdKv_pvID22Utdnpb8CizqlEA&oe=62462893&_nc_sid=a9513d']},
#  {'userid': [4091161308],
#   'username': ['gokongstore2'],
#   'is_private': [False],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [650],
#   'followees': [7430],
#   'external_url': ['https://gokongstore.com/daftar-harga/'],
#   'is_business_account': [True],
#   'business_category_name': ['Personal Goods & General Merchandise Stores'],
#   'biography': ['Cek Bukti Pembeli?\nDi Highlights 👉 @gokongstore \nCek Harga? di Website\n(Klik link di Bio)'],
#   'full_name': ['Gokong Store'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/132611406_225746355621299_4222950266990493424_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=JOr9D9oqVScAX-RCnuW&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_qsDnG64MTcSb-gJHR2EyJsSTOdODjiaXLAHWvMCkgvA&oe=62453324&_nc_sid=a9513d']},
#  {'userid': [47093709],
#   'username': ['mettaadytia'],
#   'is_private': [True],
#   'mediacount': [263],
#   'igtvcount': [3],
#   'followers': [925],
#   'followees': [4380],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['wife and mother of three \ngood vibes only 🌻'],
#   'full_name': ['Meta Nurul Adytia 💎'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/928592_526494300828550_1000230840_a.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=q4DhEgQnE6wAX9n-BTx&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8H5RaGHRGIrC64LHL6PZL0PDHealyj79zIcle4t9-JTg&oe=6244C004&_nc_sid=a9513d']},
#  {'userid': [8647909679],
#   'username': ['diniar_paramesti'],
#   'is_private': [True],
#   'mediacount': [41],
#   'igtvcount': [5],
#   'followers': [1873],
#   'followees': [4395],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Diniar Anisya Septypuri'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/127987482_381529746451528_5344721856173342809_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=V2nbJfY8M5MAX-Xj-iH&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_8AaQe33G8nPG9ViTFxQfMOteMU7anz5DSBpFYWCwS9A&oe=6244AEF1&_nc_sid=a9513d']},
#  {'userid': [4120190314],
#   'username': ['devi.ardi83'],
#   'is_private': [True],
#   'mediacount': [316],
#   'igtvcount': [89],
#   'followers': [458],
#   'followees': [572],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Moms @kalealakei_ And @danellaveaa\n 👉@dekade.foodndrink'],
#   'full_name': ['Dvie Ardie'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/223500542_318055280005673_4783439789489083433_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=105&_nc_ohc=NsgrrUJewyMAX9t8z3U&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-l8J9gAxUOmDdP64DcM71bbQFSKFh9gzu4SP1tY7_e-A&oe=62458F9E&_nc_sid=a9513d']},
#  {'userid': [2239156946],
#   'username': ['permanawatireni'],
#   'is_private': [False],
#   'mediacount': [910],
#   'igtvcount': [59],
#   'followers': [626],
#   'followees': [1609],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Reni Permanawati'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/247717861_125184313222651_860115233136212165_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=t08ULL7Xj4AAX8C66-4&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-83oTjrAlmwTsNQLm42T9VXmUMy_QgSJ5QMkFr8_B2qw&oe=6245B6DE&_nc_sid=a9513d']},
#  {'userid': [48563781165],
#   'username': ['snowyu24'],
#   'is_private': [True],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [4],
#   'followees': [221],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Someone'],
#   'full_name': ['Tre'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/210534464_184902900254445_8851005889854513863_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=xEpcC5bIguoAX_-Sz3f&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9QIpY4VdRGJ0uvhl78jiJExWPfFoJFR7Fcq3NGzgn2Yw&oe=62447CD2&_nc_sid=a9513d']},
#  {'userid': [46003143822],
#   'username': ['floris_azz2'],
#   'is_private': [False],
#   'mediacount': [34],
#   'igtvcount': [17],
#   'followers': [348],
#   'followees': [1200],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Semarang CITY ✨\n📍 MTJ RT 5 Rw 4 🦋\nZona Astetic 🙌'],
#   'full_name': ['Jelita Floris'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/245030516_300068491591063_3594005644009112357_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=FFi3i2HWYCEAX8NN0m4&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-HU0u0tF9tF-_OVtjVI07uNK6IiuOqHdyWcu4-IlqfQw&oe=6244610F&_nc_sid=a9513d']},
#  {'userid': [48773680113],
#   'username': ['ff.iqbal143'],
#   'is_private': [False],
#   'mediacount': [2],
#   'igtvcount': [2],
#   'followers': [124],
#   'followees': [175],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Muhammad Iqbal Saputra 🕊️✨🖤\nMy bestie ✨🖤\n@ah_jelita \n@ah_ainii \n@ff.joshua17 \n@fferika4 \n@ffputri793 \nPunya ku semua itu 💗✨'],
#   'full_name': ['iQbal• ni genk 🕊️✨'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/212705844_3036404419930384_2280553797567091846_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=5JMRcRM_-mgAX8eSxAg&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9qwR3sD30PHClYBwYR52DYkQxGv5QWriwIqiAwqparHg&oe=6244B799&_nc_sid=a9513d']},
#  {'userid': [48725779958],
#   'username': ['arshdeep_5842singh'],
#   'is_private': [False],
#   'mediacount': [8],
#   'igtvcount': [0],
#   'followers': [54],
#   'followees': [1104],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Akashdeep'],
#   'full_name': ['Arshdeep 5842 Singh'],
#   'has_public_story': [False],
#   'is_verified': [False],
# ...
#   'mediacount': [823],
#   'igtvcount': [102],
#   'followers': [1576],
#   'followees': [2562],
#   'external_url': ['https://sites.google.com/view/astriarizayanti/beranda'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Bundanya Khanza & Shabira 💕Akun Bisnis klik @khashamsglowbandung ID MSGLOW037.85.19 Reseller Resmi @mkdailywear_bandungtimur'],
#   'full_name': ['Astria Rizayanti'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/250295254_180344824271604_5723592052410589631_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=07aOvABOXyQAX8iXnfp&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_nYa1z05xm3FdEab2D5KYRsQAc1YAgfYSp_NYKmgCDIw&oe=62446932&_nc_sid=a9513d']},
#  {'userid': [46578031315],
#   'username': ['raj.kushawaha.58910049'],
#   'is_private': [False],
#   'mediacount': [4],
#   'igtvcount': [0],
#   'followers': [528],
#   'followees': [3883],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Raj Kushawaha'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/277078874_136073792266713_7102513294809986761_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=NOaL5XTanU0AX-tkGPw&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9mVhsNniYQRQNfHozRIwLmDtUIlhFDpw79F0FQm-d1RA&oe=62447735&_nc_sid=a9513d']},
#  {'userid': [1301889189],
#   'username': ['varisarosdini'],
#   'is_private': [True],
#   'mediacount': [389],
#   'igtvcount': [22],
#   'followers': [807],
#   'followees': [1457],
#   'external_url': ['https://linktr.ee/forearly4mom'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Please join \n@forearly\n@mirai.clothing \n@pinewood_project'],
#   'full_name': ['Dini Mirai'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/244439220_593701251984563_5838154358504748757_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=qJemYlbRvc0AX92Bjwj&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-GwHN9iWjKI0_nKVMmR3iUW11rV-uLexaVNbzYuplvvA&oe=6245554F&_nc_sid=a9513d']},
#  {'userid': [4086571464],
#   'username': ['bettysukmana'],
#   'is_private': [False],
#   'mediacount': [299],
#   'igtvcount': [29],
#   'followers': [754],
#   'followees': [731],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Betty Z Sukmana'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/271873078_4710064085715003_7096533064973434973_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=CDxNY6i8nowAX858xtR&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8Cus1QV-hFV-A7X_EfunWxUW9_7syY3cbTajt3qhnjQw&oe=6245D714&_nc_sid=a9513d']},
#  {'userid': [711886824],
#   'username': ['dewijulia_wok'],
#   'is_private': [True],
#   'mediacount': [300],
#   'igtvcount': [27],
#   'followers': [393],
#   'followees': [473],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['"Membingkai rasa dalam kata"'],
#   'full_name': ["Dewi 'wok'Juliawati"],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/275393220_335002008579440_6305859675809978468_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=R1B5ltLrZuYAX8GTHPp&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_FID632TyK5C5F-DIeJ_Q2TcaoVrUSR28H2D7QcANH7A&oe=6244B5C4&_nc_sid=a9513d']},
#  {'userid': [213092506],
#   'username': ['tennyradestriana'],
#   'is_private': [True],
#   'mediacount': [417],
#   'igtvcount': [34],
#   'followers': [574],
#   'followees': [540],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Tenny'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/87220044_2584236185141806_1193939133773381632_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=110&_nc_ohc=r0m8hAfVkRsAX_OQgou&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-EEZInRYjFioC2wxFf2vsdwPvk0Faz9et5rbe-gf-tBw&oe=6245228D&_nc_sid=a9513d']},
#  {'userid': [1225726169],
#   'username': ['rinasusanti7587'],
#   'is_private': [True],
#   'mediacount': [359],
#   'igtvcount': [20],
#   'followers': [846],
#   'followees': [1052],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Rina Susanti'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/241061171_1531582133843431_7180919522920222703_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=dQFyVu4GMDQAX_chc0E&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT88OGXmkkViuX_g2VEXAZtQjUlf_MHGbjCTVZihDZLkWg&oe=62458D09&_nc_sid=a9513d']},
#  {'userid': [277548976],
#   'username': ['tomtomtomia'],
#   'is_private': [False],
#   'mediacount': [84],
#   'igtvcount': [3],
#   'followers': [658],
#   'followees': [820],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Siti Qomariah'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/275013210_146715187814612_7342757991172515744_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=uVMF54UIPXAAX9UgDju&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-qIoCHGpa9URI5nLf3NK1gJAa-b9qDfERH3Odmvx7djw&oe=6244EFB2&_nc_sid=a9513d']},
#  {'userid': [47882180758],
#   'username': ['bintangbinyang72'],
#   'is_private': [False],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [89],
#   'followees': [272],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['bintangbinyang7'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/195017746_210634067565021_9107577192932004570_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=J74M_oqwLssAX-Y_kS7&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_cKpnXwytOt6YHrtCcomRIO8tvx-k2vPZyHhwLRlAcag&oe=6244B035&_nc_sid=a9513d']},
#  {'userid': [47721167965],
#   'username': ['iriemwinblack'],
#   'is_private': [False],
#   'mediacount': [0],
#   'igtvcount': [0],
#   'followers': [53],
#   'followees': [193],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Iriemwin Black'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/195211353_627073374873587_4229702117907829674_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=oHHLDyXXIfAAX9nRlEw&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT891F-aYkYiDy9CnJup-cZTYgBeDD2ZwNWE7uNshiELcA&oe=62450B0A&_nc_sid=a9513d']},
#  {'userid': [48106032772],
#   'username': ['jay_12249'],
#   'is_private': [False],
#   'mediacount': [8],
#   'igtvcount': [4],
#   'followers': [478],
#   'followees': [1991],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Wa;088246235370'],
#   'full_name': ['@jay_12'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/238425044_1158702097941265_8421639925841497571_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=101&_nc_ohc=RiqgNCsQabgAX_5UqSe&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_yIrjaB-dEyNpOcBz1VceGiO55x80ZRds4zC91pgUg9g&oe=62450F2B&_nc_sid=a9513d']},
#  {'userid': [47619273304],
#   'username': ['akhaphotography'],
#   'is_private': [False],
#   'mediacount': [10],
#   'igtvcount': [0],
#   'followers': [36],
#   'followees': [107],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['PhotoGraphy'],
#   'full_name': ['akhaphotography'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/263737482_1071466157022904_5239305151095609113_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=9q0y159Q7TEAX9bONtY&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT8NNi2TLFXaCWwga21pgtI4Rxb0nla2V-mB7aJMwK6mkQ&oe=62450ED0&_nc_sid=a9513d']},
#  {'userid': [34674484295],
#   'username': ['carlendy_cartel'],
#   'is_private': [False],
#   'mediacount': [2],
#   'igtvcount': [1],
#   'followers': [223],
#   'followees': [707],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Carl Anderson nerette'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/275400739_463324508835583_1823522085530947773_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=rXMBJxh6PUsAX-bW0ri&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT888sb7T4SaqMp5jEjACSO79milNNYLBWlAh8mRtZOlyA&oe=6244EAA7&_nc_sid=a9513d']},
#  {'userid': [47440285767],
#   'username': ['moussa_tayc_mara'],
#   'is_private': [False],
#   'mediacount': [5],
#   'igtvcount': [3],
#   'followers': [130],
#   'followees': [1318],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Moussa officiel 224💖\nTout pour le buzz 🤑\n#Go follow #'],
#   'full_name': ['Møussā Akim Mārā'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/277031596_910939459585014_8220312565424002969_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=KwFhD1IhgKcAX8O4STG&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-7IzX4fa8NYr2PbjhNdQkqxLqImB9kP-EgLJ6iJOf0mg&oe=6244CE4A&_nc_sid=a9513d']},
#  {'userid': [47640643809],
#   'username': ['mivekanneofficiel'],
#   'is_private': [False],
#   'mediacount': [18],
#   'igtvcount': [9],
#   'followers': [1370],
#   'followees': [6934],
#   'external_url': [None],
#   'is_business_account': [True],
#   'business_category_name': ['Creators & Celebrities'],
#   'biography': ['Artiste // Compositeur // Chanteur // Rappeur 🇧🇯'],
#   'full_name': ['Mivekanne Officiel'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/274332145_334699998586278_4374190904395080729_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=5nEOgcnC2MQAX8nyxKP&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_363MdF9UYlwB4a_LoEc1v7Cmt-de7yeER4cWyOuUruQ&oe=62456631&_nc_sid=a9513d']},
#  {'userid': [1388886581],
#   'username': ['meaqr'],
#   'is_private': [True],
#   'mediacount': [25],
#   'igtvcount': [1],
#   'followers': [509],
#   'followees': [1019],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['Bismillah'],
#   'full_name': ['Mea Qattalina Rolland'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/270020853_1277520716086538_3029714928999144680_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=P4b0c0BZdSoAX8zGDZo&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_TwdasmYp4x8zE12MNBKjPJStWW4YTxdfWlOYYBfD6Fg&oe=6244D3B6&_nc_sid=a9513d']},
#  {'userid': [47771423500],
#   'username': ['abrorjonurinov70'],
#   'is_private': [False],
#   'mediacount': [2],
#   'igtvcount': [0],
#   'followers': [50],
#   'followees': [494],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': ['Аброржон'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fkix2-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fkix2-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=kLQ4jXKOCJIAX-YwYLY&edm=ALlQn9MBAAAA&ccb=7-4&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4&oh=00_AT_-DMpUVP1AP0zL7k4Q2tHHvUI5U7cpEe0nH7J67rF_5g&oe=624465CF&_nc_sid=48a2a6']},
#  {'userid': [22133699597],
#   'username': ['hectoreben5'],
#   'is_private': [False],
#   'mediacount': [73],
#   'igtvcount': [22],
#   'followers': [1282],
#   'followees': [4005],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['benhectore'],
#   'full_name': ['hectoreben'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/162646559_783480565931187_6339827648420049545_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=103&_nc_ohc=LcY6OGCKxOoAX-jyNLl&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_hhWHpSN4b8vTa8qr5CGmIWAsa7LAnVaayqMCGN41Upw&oe=62449C9E&_nc_sid=a9513d']},
#  {'userid': [29214955627],
#   'username': ['kervens4707'],
#   'is_private': [False],
#   'mediacount': [7],
#   'igtvcount': [3],
#   'followers': [1177],
#   'followees': [3057],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': [''],
#   'full_name': [''],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-1.fna.fbcdn.net/v/t51.2885-19/208962426_552598509271326_6426996362903777144_n.jpg?_nc_ht=instagram.fbdo1-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=9dJif6zR8JoAX966VTO&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT-EjUyHCAlRTc_Rzix_yutNGL-1ApJCmfBWk5fFQudjEA&oe=62455F30&_nc_sid=a9513d']},
#  {'userid': [47821570955],
#   'username': ['ak.hileshkumar515'],
#   'is_private': [False],
#   'mediacount': [15],
#   'igtvcount': [4],
#   'followers': [201],
#   'followees': [1478],
#   'external_url': [None],
#   'is_business_account': [True],
#   'business_category_name': ['Creators & Celebrities'],
#   'biography': ['Akhilesh Kumar comedy show  singar'],
#   'full_name': ['akhileshkumar'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_cat=1&_nc_ohc=kLQ4jXKOCJIAX_-U-dJ&edm=AJ9x6zYBAAAA&ccb=7-4&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-4&oh=00_AT8bdkIcoeihh8oV2B5Mb_1rQfxnDrwI1vhwJpvg-VGFfA&oe=624465CF&_nc_sid=cff2a4']},
#  {'userid': [47827615992],
#   'username': ['dayal3789'],
#   'is_private': [False],
#   'mediacount': [42],
#   'igtvcount': [15],
#   'followers': [255],
#   'followees': [1756],
#   'external_url': [None],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['अंकित'],
#   'full_name': ['Shiv dayal'],
#   'has_public_story': [False],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/256353417_278616040708415_9143827035748636244_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=zwUar1ycPJMAX_Ybk1n&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT_49xmP6FFoag0GOXm47ExRyH0488vm_IVDlfwIgwFBjQ&oe=6245C873&_nc_sid=a9513d']},
#  {'userid': [11686232],
#   'username': ['lilyanaputri'],
#   'is_private': [False],
#   'mediacount': [1056],
#   'igtvcount': [72],
#   'followers': [1977],
#   'followees': [1514],
#   'external_url': ['https://wa.me/6281285318673'],
#   'is_business_account': [False],
#   'business_category_name': [None],
#   'biography': ['✨ @essentialoil.bandung @mamiya.authentic @jasatitip.dibandung @hampersbymiya ✨ #FatlossEnthusiast'],
#   'full_name': ['Lilyana Putri'],
#   'has_public_story': [True],
#   'is_verified': [False],
#   'profile_pic_url': ['https://instagram.fbdo1-2.fna.fbcdn.net/v/t51.2885-19/274930779_497522845367852_8145023447586100557_n.jpg?_nc_ht=instagram.fbdo1-2.fna.fbcdn.net&_nc_cat=108&_nc_ohc=l857hoBDSs4AX8kH4Iy&edm=AEF8tYYBAAAA&ccb=7-4&oh=00_AT9NLxiMLUXnuSJN7a7t6tvqhtuvDThAGI8kR9LbvOcM0w&oe=6245A707&_nc_sid=a9513d']}]

# %%
pd.DataFrame(list_followers).to_csv("hasil_c5.csv")

# %% [markdown]
# # 6
#
# <tr><td>F-Q</td>
# <td>https://www.linkedin.com/company/bank-mandiri/</td></tr>

# %%
# login
link = 'https://www.linkedin.com/login/in?fromSignIn=true&trk=guest_homepage-basic_nav-header-signin'
open_driver(link)
xpath = '//input[@id="username"]'
fill_in(xpath, '') # diisi
xpath = '//input[@id="password"]'
fill_in(xpath, '') # diisi
xpath = '//button[@class="btn__primary--large from__button--floating"]'
get_single_element(xpath).click()
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver_path)
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   return driver.find_element_by_xpath(xpath)

# %%
link = 'https://www.linkedin.com/company/bank-mandiri/'
driver.get(link)

# %%
xpath = '//*[@id="ember35"]/div[2]/div[1]/div[1]/div[2]/div/h1/span'
name = get_content(xpath)
## alternatif
# name = driver.find_element_by_class_name("t-24").get_attribute("title")
name
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   return driver.find_element_by_xpath(xpath)
# 'PT Bank Mandiri (Persero) Tbk.'

# %%
xpath = '//*[@id="ember35"]/div[2]/div[1]/div[1]/div[2]/div/p'
try:
    bio = get_content(xpath)
    ## alternatif
    # bio = driver.find_element_by_class_name("org-top-card-summary__tagline").text
except:
    bio = None
    print("No bio")
bio
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   return driver.find_element_by_xpath(xpath)
# '#11 Best Employers in "Global 2000: World\'s Best Employers"\u200b (by Forbes.com)'

# %%
xpath = '//*[@id="ember35"]/div[2]/div[1]/div[1]/div[2]/div/div/div[2]/div[2]'
c_followers = get_content(xpath)
## alternatif
# c_followers = driver.find_element_by_class_name("org-top-card-secondary-content__see-all").text
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\1105613198.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   return driver.find_element_by_xpath(xpath)

# %%
c_followers = c_followers.split()[0]

# %%
c_followers = c_followers.replace(",", "")
c_followers
# Out:
# '305269'

# %%
res = {
    "nama": name,
    "bio": bio,
    "followers": c_followers
}

res
# Out:
# {'nama': 'PT Bank Mandiri (Persero) Tbk.',
#  'bio': '#11 Best Employers in "Global 2000: World\'s Best Employers"\u200b (by Forbes.com)',
#  'followers': '305269'}

# %% [markdown]
# # Bonus

# %%
# menuju link employees
xpath = '//*[@id="ember40"]'

button = driver.find_element_by_xpath(xpath)

button.click()
# Out:
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\783039617.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath(xpath)

# %%
print("Menampilkan link semua karyawan pada halaman pertama pencarian")
for e in driver.find_elements_by_class_name("entity-result__title-text"):
    a = e.find_element_by_class_name("app-aware-link").get_attribute("href")
    print(a)
# Out:
# Menampilkan link semua karyawan pada halaman pertama pencarian
# https://www.linkedin.com/in/tashatantyani?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAB-BS1kBf24SkkiQe439SAoxljvxyhUHIww
# https://www.linkedin.com/in/muhammad-feisal-gibran-maulana-473243199?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC58wtcBaf53uYyN8K12XdJsH3hWQ_F9KMU
# https://www.linkedin.com/in/dinar-aprilla-sari?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC_vApoBR66oAByW5Ik4nI3FdKe37KKCi1A
# https://www.linkedin.com/in/mifthahul-jannah-807087192?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC03m8cBe-7Cv7hcA4NxQXWVuf3L-gwAKHU
# https://www.linkedin.com/in/falih-prayogo-77b02817a?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACpcvE8Bo9j1nZuHG6ZLNX7lX158SKzZgc4
# https://www.linkedin.com/in/bagus-isattama?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAS-4m4BBSFkxQkTaSkyB3a0eoPJVbMnDmo
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\3081633066.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for e in driver.find_elements_by_class_name("entity-result__title-text"):
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:446: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# https://www.linkedin.com/in/grace-anneke-81327221?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAAR88Q8BhY9G2ayp6oSZVc_21mm3Xh3w_18
# https://www.linkedin.com/in/rika-fitria-septiani-919aa4141?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACKC0iUB-sR6Dfo06XhKik19SFOBTB3ZDuw
# https://www.linkedin.com/in/jasmine-alya-nisa?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC04JzEB-WhO-SNz6mUelsaYBjvEYOMujac
# https://www.linkedin.com/in/septian-yosdiawan-65b19a92?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABOazCcBuTgfjhRKab6iHXAiMui45TVIJWQ

# %%
print("Menampilkan link semua karyawan pada halaman pertama pencarian dan kontak yang berhungan dengan saya")
el = driver.find_elements_by_class_name('app-aware-link')

list_link = []
for link in el:
    this_link = link.get_attribute("href")
    if this_link not in list_link:
        print(this_link.split("?")[0])
        list_link.append(this_link)
# Out:
# Menampilkan link semua karyawan pada halaman pertama pencarian dan kontak yang berhungan dengan saya
# https://www.linkedin.com/in/tashatantyani
# https://www.linkedin.com/in/ACoAACptsvABpMeDLFMX3AT70ss-dnRiWAZT7Bg
# https://www.linkedin.com/in/muhammad-feisal-gibran-maulana-473243199
# https://www.linkedin.com/in/ACoAABtYq78BLNlun6E2qLqlydJzUIXpQ7ViOrg
# https://www.linkedin.com/in/dinar-aprilla-sari
# https://www.linkedin.com/in/ACoAADVmNsYBKbK0eTFQID8QszLkwttSRWVDoCI
# https://www.linkedin.com/in/ACoAADZDOiQBWmbGZfpWwQOItJmRwdJ54vrpjOs
# https://www.linkedin.com/in/mifthahul-jannah-807087192
# https://www.linkedin.com/in/ACoAAAQM6GcB9AIzhssnAnhaKSKdOBnZm3vKQBo
# https://www.linkedin.com/in/falih-prayogo-77b02817a
# C:\Users\ichsan\AppData\Local\Temp\ipykernel_14888\2000479343.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   el = driver.find_elements_by_class_name('app-aware-link')
# https://www.linkedin.com/in/ACoAADR4SqQBlb_o4XZe6npli6cE0-Shjpb_HCw
# https://www.linkedin.com/in/bagus-isattama
# https://www.linkedin.com/in/ACoAAA03CnIBvlad8miIWhvJ7NYOBTSRd3bP5UQ
# https://www.linkedin.com/in/grace-anneke-81327221
# https://www.linkedin.com/in/rika-fitria-septiani-919aa4141
# https://www.linkedin.com/in/ACoAACyDj6sB2HZEMdJLISlAS_KG8k7iOXuW1DQ
# https://www.linkedin.com/in/ACoAADebHLcB9i16m7hzHXux3AfCGyYt5LbBF4M
# https://www.linkedin.com/in/jasmine-alya-nisa
# https://www.linkedin.com/in/ACoAADPsohMBrWnyGa8vfgAFLEtafZYWBohZBSc
# https://www.linkedin.com/in/septian-yosdiawan-65b19a92
